# %% [markdown]
# ##### Loop over filters 64 128 256

# %%
name_df_res = 'df_res_filters_gu0_50nod'

# initializers 
init_he_n = keras.initializers.he_normal(seed=0)
init_glorot_u = keras.initializers.glorot_uniform(seed=0)
# Hyper-parameters
lr = 3e-8
decay = 1e-6
momentum = 0.9
nesterov = True 
#nb_filters = 320 # Conv2D layers
nb_nodes = 50 # first FC layer
conv_init = init_glorot_u # Conv2D layers
dens_init = init_glorot_u # First FC Dense layer
out_init = init_glorot_u # Output FC Dense layer

# Fitting parameters
epochs = 150
batch_size = None
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', 
                                   verbose=1, patience=30,
                                   restore_best_weights=True)
# init output variables
df_res = None
#list_nb_filters = []
#list_nb_try = []

# loop on nb filter to check if accuracy is better and memory not saturated
for nb_filters in [64, 128, 256, 320]:
  print("nb_filters: ", nb_filters)
  for nb_try in range(0, 3):
    print("nb_try: ", nb_try)
    #list_nb_filters.append(nb_filters)
    #list_nb_try.append(nb_try)

    # Model creation
    my_VGG16_03 = Sequential()  # Création d'un réseau de neurones vide 
    my_VGG16_03.name = 'my_VGG16_03_{}filt_gu0_50nod_{}'.format(nb_filters, 
                                                               nb_try)

    # Ajout de la première couche de convolution, suivie d'une couche ReLU
    my_VGG16_03.add(Conv2D(nb_filters, kernel_size=3, strides=1, 
                          input_shape=(224, 224, 3),
                          padding='same', activation='relu',
                          kernel_initializer=conv_init))
    my_VGG16_03.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))) # test
    # Ajout de la deuxième couche de convolution, suivie  d'une couche ReLU
    my_VGG16_03.add(Conv2D(nb_filters, kernel_size=3, strides=1, padding='same', 
                          activation='relu',
                          kernel_initializer=conv_init))

    # Ajout de la première couche de pooling
    my_VGG16_03.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))) # test
    my_VGG16_03.add(Flatten())  # Conversion des matrices 3D en vecteur 1D

    # Ajout de la première couche fully-connected, suivie d'une couche ReLU
    my_VGG16_03.add(Dense(nb_nodes, activation='relu',
                      kernel_initializer=dens_init))

    # Ajout de la dernière couche fully-connected qui permet de classifier
    my_VGG16_03.add(Dense(nb_breeds, activation='softmax',
                    kernel_initializer=out_init))
    print(my_VGG16_03.summary())

    # optimizer
    sgd_2 = optimizers.SGD(lr=lr, decay=decay, momentum=momentum, 
                           nesterov=nesterov) 
    # compile model
    my_VGG16_03.compile(loss="categorical_crossentropy", optimizer=sgd_2, 
                    metrics=["accuracy"])

    t_fit_0 = time.time()
    # fitting
    model_info_3 = my_VGG16_03.fit(X_train, Y_train, epochs=epochs, 
                                batch_size=batch_size, verbose=2,
                                validation_data=(X_test, Y_test),
                                callbacks=[es])
    t_fit_1 = time.time()
    print("Timing: ", t_fit_1 - t_fit_0)

    # save : model info
    joblib.dump(model_info_3.history, 
                path_data + 'hist_' + my_VGG16_03.name + '.pkl'.\
                format(nb_filters, nb_try), compress=True)
    print("model_info_3 history Saved here:\n{}".\
          format(path_data + 'hist_' + my_VGG16_03.name + '.pkl'.\
                format(nb_filters, nb_try)))

    # plot results at each iterations
    plot_history(model_info_3.history)

    #  save
    my_VGG16_03.save(path_data + my_VGG16_03.name + '.h5')

    # predict as binary labels
    t_pred_0 = time.time()
    Y_train_pred = my_VGG16_03.predict(X_train)
    t_pred_1 = time.time()
    # predict as binary labels
    t_pred_2 = time.time()
    Y_test_pred = my_VGG16_03.predict(X_test)
    t_pred_3 = time.time()

    # prepare results
    series_scores = evaluate_mdl_scorings(Y_train, Y_train_pred, 
                                      Y_test, Y_test_pred, 
      timing_fit=t_fit_1 - t_fit_0, 
      timing_pred=t_pred_3-t_pred_2+t_pred_1-t_pred_0)
    df_res = add_score(df_res, series_scores, my_VGG16_03.name)
    df_res.at[my_VGG16_03.name,"nb_filters"] = nb_filters
    df_res.at[my_VGG16_03.name,"nb_try"] = nb_try
    # save results
    joblib.dump(df_res, path_data + name_df_res + '.pkl', compress=True)
    print(name_df_res + " Saved here:\n" + path_data + name_df_res + '.pkl')

# save results
joblib.dump(df_res, path_data + name_df_res + '.pkl', compress=True)
print(name_df_res + " Saved here:\n" + path_data + name_df_res + '.pkl')
    
exec(name_df_res+'=df_res.copy()')
exec(name_df_res)

# %%
df_res_filters_gu0_50nod

# %%
print("Loading from disk df_results...")
df_results = joblib.load(path_df_results)
print("Loading from disk df_res_filters...")
df_res_filters = joblib.load(path_data + 'df_res_filters.pkl')
print("Loading from disk df_res_nodes...")
df_res_nodes = joblib.load(path_data + 'df_res_nodes.pkl')
print("Loading from disk df_res_filters_max...")
df_res_filters_max = joblib.load(path_data + 'df_res_filters_max.pkl')
print("Loading from disk df_res_filters_he_50nod.pkl...")
df_res_filters_he_50nod = joblib.load(path_data + 'df_res_filters_he_50nod.pkl')
print("Loading from disk df_res_filters_gu0_50nod.pkl...")
df_res_filters_gu0_50nod = joblib.load(path_data + 'df_res_filters_gu0_50nod.pkl')

# %%
sns.catplot(x="nb_filters", y="acc_test", kind="box", 
            data=df_res_filters_gu0_50nod);

# %%
ax = sns.regplot(x="nb_filters", y="acc_test", data=df_res_filters_gu0_50nod);
ax.set_title("Improve accuracy with nb conv. filters");

# %%
ax = sns.regplot(x="nb_filters", y="t_fit", data=df_res_filters_gu0_50nod);
ax.set_title("Increase of time with number of conv. filters")

# %%
nb_splits = df_res_filters_gu0_50nod["nb_try"].nunique()
def confid_interv(value):
  return 1.96*np.std(value)/np.sqrt(nb_splits)
df_filters = df_res_filters_gu0_50nod.pivot_table(values=["acc_test",	
                                                         "acc_train", 
                                                "t_fit",	"t_pred"],
                           index="nb_filters", aggfunc={np.mean, confid_interv})
df_filters

# %%
df_filters["nb_filters"] = df_filters.index
ax = sns.regplot(x=df_filters["nb_filters"] , y=df_filters[("acc_test","mean")]);
ax.set_title("Improve mean test accuracy with nb conv. filters");
ax.set_ylim([0.3,0.5])
plt.errorbar(df_filters["nb_filters"], df_filters[("acc_test","mean")], 
             yerr=df_filters[("acc_test","confid_interv")], uplims=True, 
             lolims=True);

# %% [markdown]
# ## IML_Projet_6
# Classez des images à l'aide d'algorithmes de Deep Learning
#
# Ce note book contient :
# - La creation et le test de mon propre reseau de neurone CCN

# %%
import os
import pprint
import tensorflow as tf
tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
with tf.Session(tpu_address) as session:
  devices = session.list_devices()
    
print('TPU devices:')
pprint.pprint(devices)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-ed92e1f7610c> in <module>()
#       2 import pprint
#       3 import tensorflow as tf
# ----> 4 tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
#       5 with tf.Session(tpu_address) as session:
#       6   devices = session.list_devices()
#
# /usr/lib/python3.6/os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'COLAB_TPU_ADDR'

# %% [markdown]
# ## Data mount drive folder

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/OpenClassRooms/IML_Projet_6/code/DeepLearningPictureDogs
# Out:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/code/DeepLearningPictureDogs

# %%
# !ls
# Out:
# 01_OC_IML_Project_6_explorations.ipynb	       my_utils_dogs.py
# 02_OC_IML_Project_6_my_neural_network.ipynb    __pycache__
# 03_OC_IML_Project_6_my_neural_network_2.ipynb  README.md

# %% [markdown]
# ## Import

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import seaborn as sns
sns.set(color_codes=True, font_scale=1.33)

import os

import re

import pickle

import time

from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import label_binarize

import numpy as np
import pandas as pd
pd.set_option("display.max_columns", 25)

import scipy.io as sio

from PIL import Image
from PIL import ImageOps
from PIL import ImageFilter
import cv2 as cv

import tensorflow
print(tensorflow.__version__)

# keras from scratch
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Flatten, Dense
from keras.models import load_model
# keras already trained
from keras.applications.vgg16 import VGG16
# keras image preparation
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
# decode prediction
from keras.applications.vgg16 import decode_predictions
# for training keras model : optimizers
from keras import optimizers
# Keras model base
from keras.models import Model

import json

# ne marche pas (une modif d'une fonction d'un module ne se répercute pas)
# import user module
#from my_utils_dogs import find_breed
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0
# Using TensorFlow backend.

# %% [markdown]
# ## Definitions

# %%
path_data = '/content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/'
path_file_list = 'lists/file_list.mat'
path_test_list = 'lists/test_list.mat'
path_train_list = 'lists/train_list.mat'
path_test_data = 'test_data.mat'
path_train_data = 'train_data.mat'

paths_images_all_breeds = ['Images/n02107683-Bernese_mountain_dog/',
                     'Images/n02088094-Afghan_hound/',
                     'Images/n02096051-Airedale/',
                     'Images/n02090721-Irish_wolfhound/',
                     'Images/n02091831-Saluki/',
                     'Images/n02092002-Scottish_deerhound/',
                     'Images/n02096294-Australian_terrier/',
                     'Images/n02095889-Sealyham_terrier/',
                     'Images/n02095570-Lakeland_terrier/',
                     'Images/n02110185-Siberian_husky/']

nb_breeds = 3
paths_images_breeds = paths_images_all_breeds[:nb_breeds]

path_img_test = path_data + 'Images/n02085620-Chihuahua/' + "n02085620_242.jpg"

path_df_dogs = path_data + 'df_dogs.pkl'
path_X_images = path_data + 'X_images.pkl'
path_Y_images = path_data + 'Y_images.pkl'

name_new_model_2 = 'VGG16_TL_class_01'
path_model_2 = path_data +  name_new_model_2 + '.pkl'

path_df_results = path_data + 'df_results.pkl'

path_imagenet = path_data + 'Images/imagenet_class_index.json'

train_percent = 0.7

# %% [markdown]
# ## Useful functions

# %%
def import_data(paths_images_breeds, train_percent=0.7, force_import=False,
                path_df_dogs=path_df_dogs, path_X_images=path_X_images,
                path_train_list=None):
  '''
  Import data from images on disk

  3 possibilites if force_import = False:
  (1) no data on disk, no data in memory :
    - create df_dogs & X from image files 
    - separate train / test set for df_dogs
  (2) data pickled on disk, no data in memory : 
    - load data from pickled files for df_dogs & X
    - separate train / test set for df_dogs
  (3) data in memory
    - use df_dogs & X from memory 
    - separate train / test set for df_dogs
    - save df_dogs & X on disk
  
  if force_import = True, only  read from image files (1) is possible.

  example: import from memory or already pickled files on disk, with 70% train: 
    df_dogs, X, dict_breed = import_data(paths_images_breeds)
  
  '''
  # import from already processed pickle files on disk
  try:
    if force_import == False:
      df_dogs, X, dict_breed = load_data_breeds() # to load if not exist
      #df_dogs = separate_train_by_class(df_dogs, train_percent=train_percent)
      return df_dogs, X, dict_breed 
  except:
    # if not in memory and not on disk
    pass # continue with importation from images files on disk
  

  # import from image files on disk
  df_dogs = pd.DataFrame(columns=["filename", "path", "breed", "class", 
                                  'Train'])
  # read images in source folders
  X=None
  for id, path_curr in enumerate(paths_images_breeds):
    breed_curr = re.findall('\w+(?=/$)', path_curr)
    print(breed_curr)
    for filename in os.listdir(path_data + path_curr):
      df_add = pd.DataFrame(columns=["filename", "path", "breed", "class", 
                                     "Train"], 
                          index =[0])
      df_add["filename"] = filename
      df_add["path"] = path_data + path_curr + filename
      df_add["breed"] = breed_curr
      df_add["class"] = id
      df_dogs = df_dogs.append(df_add, ignore_index=True)
      # create X image matrix
      img = load_img(df_add["path"].values[0], 
               target_size=(224, 224))  # Charger l'image
      img = img_to_array(img)  # Convertir en tableau numpy
      if X is None:
        X = img[np.newaxis, :]
      X = np.concatenate((X, img[np.newaxis, :]), axis=0)

  # seperate train/test 
  # check test/train mode
  if path_train_list is not None:
    print('Train/Test separation by mat')
    mat_train = sio.loadmat(path_data + path_train_list)
    df_train = pd.DataFrame(data=mat_train["file_list"], 
                           columns=["filename_brut"])
    df_train["filename"] = df_train["filename_brut"].apply(apply_find_filename)
    df_dogs["Train"] = df_dogs["filename"].apply(check_file_train, 
                                                 args=(df_train,))
  else:
    print('Train/Test separation by percent')
    df_dogs = separate_train_by_class(df_dogs, train_percent=train_percent)   
  # preprocess image data for VGG-16
  X = preprocess_input(X)

  # find breed name
  dict_breed = dict()
  for id_class in df_dogs["class"].unique(): 
    dict_breed[id_class] = df_dogs[df_dogs["class"] == \
                                 id_class]["breed"].values[0]
  
  # save on disk
  save_data(df_dogs, path_df_dogs, X, path_X_images)

  return df_dogs, X, dict_breed

def check_file_train(filename, df_train):
  '''
  Apply function for dataFrame column to check Train file from data
  '''
  if filename in df_train["filename"].values:
    return True
  else:
    return False

def apply_find_filename(value):
  '''
  apply function for dataFrame column to extract filename from text

  example : 
    [n02085620-Chihuahua/n02085620_5927.jpg]	-> n02085620_5927.jpg
  '''
  return re.findall('(?<=/).+', value[0])[0]

def load_data_breeds(force_reload=False, path_df_dogs=path_df_dogs,
                     path_X_images=path_X_images):
  '''
  Load data from disk if variable df_dogs & X is not available in memory

  Optional parameter force_reload can be use to force reload in any case.

  example : df_dogs, X, dict_breed = load_data_breeds() # to load if not exist
  '''
  # df_dogs
  if force_reload == False:
    try:
      if df_dogs is not None:
        df_out = df_dogs
      else:
        print("Loading from disk df_dogs...")
        df_out = joblib.load(path_df_dogs)
    except:
      print("Loading from disk df_dogs...")
      df_out = joblib.load(path_df_dogs)
  else:
    print("Loading from disk df_dogs...")
    df_out = joblib.load(path_df_dogs)
  # X images
  if force_reload == False:
    try:
      X_out = X
    except:
      print("Loading from disk X images...")
      X_out = joblib.load(path_X_images)
  else:
    print("Loading from disk X images...")
    X_out = joblib.load(path_X_images)

  # find breed name
  dict_breed = dict()
  for id_class in df_out["class"].unique(): 
    dict_breed[id_class] = df_out[df_out["class"] == \
                                 id_class]["breed"].values[0]
  
  return df_out, X_out, dict_breed

def separate_train_by_class(df_dogs, train_percent=0.7):

  '''
  Separate TRAIN / TEST set per breed

  by default train_percent = 0.7

  add "Train" column to df_dogs

  example : df_dogs = separate_train_by_class(df_dogs, train_percent=0.7)
  '''

  df_dogs['Train'] = False
  for id_class in df_dogs["class"].unique():
    np.random.seed(0)
    indices_permut = np.random.permutation(\
      df_dogs[df_dogs["class"] == id_class].shape[0])
    indices_permut_train = \
      indices_permut[0:np.int(len(indices_permut)*train_percent)]
    index_train  = df_dogs[df_dogs["class"] == \
                         id_class].iloc[indices_permut_train].index
    df_dogs.loc[index_train, "Train"] = True

  v= df_dogs["Train"].value_counts()
  print("% of Train : {:.2f} %".format(100*v.loc[True]/sum(v)))
  print(df_dogs["Train"].value_counts())

  return df_dogs

def create_separate_features(df_dogs, X, list_X_classes=None,
                             list_Y_classes=None):
  '''
  Seperate train/test matrix of images to be use by CNN Models
  
  example : 
    X_train, X_test, Y_train, Y_test, lb = create_separate_features(df_dogs, X)
  '''
  # select from df_dogs & X only list of breed : list_X_classes
  def fun_class_ok(classNum):
    if classNum in list_X_classes:
      return True
    else:
      return False
  
  if list_X_classes is not None:
    df_in = df_dogs
    df_in["class_OK"] = False
    df_in["class_OK"] = df_dogs["class"].apply(fun_class_ok)

    df_in = df_in[df_in["class_OK"] == True]
  else:
    df_in = df_dogs
  
  # seperate train/test matrix of images 
  index_train = df_in[df_in["Train"] == True].index
  index_test = df_in[df_in["Train"] == False].index
  X_train = X[index_train,:,:,:]
  X_test = X[index_test,:,:,:]

  # prepare for Y the classes
  if list_Y_classes is None:
    lb = LabelBinarizer()
    lb.fit(df_in["class"].tolist())
    Y_train = lb.transform(df_in[df_in["Train"] == True]["class"].tolist())
    Y_test =  lb.transform(df_in[df_in["Train"] == False]["class"].tolist())
  else:
    # use list_Y_classes
    # lb function
    def lb(x):
      return label_binarize(x, classes=list_Y_classes)
    # transform train set
    Y_train = lb(
        df_in[df_in["Train"] == True]["breed"].tolist())
    # transform test set
    Y_test = lb(
        df_in[df_in["Train"] == False]["breed"].tolist())

  return X_train, X_test, Y_train, Y_test, lb

def load_prepare_img(path_img):
  '''
  Load image from path and prepare for VGG-16
  return : 
    img : np array
    img_raw : Image from PIL

  example : img, img_raw = load_prepare_img(path_img)
  '''

  img_raw = load_img(path_img, target_size=(224, 224))  # Charger l'image
  img = img_to_array(img_raw)  # Convertir en tableau numpy
  img = img[np.newaxis, :]
  img = preprocess_input(img)  # Prétraiter l'image comme le veut VGG-16
  img_raw
  return img, img_raw

def get_imagenet_classes():
  # get labels
  with open(path_imagenet) as json_data:
    class_idx = json.load(json_data)
    idx2label = [class_idx[str(k)][1] for k in range(len(class_idx))]
    # PATCH : to correct double classes
    idx2label[idx2label.index("crane")] = "crane_0"
    idx2label[idx2label.index("maillot")] = "maillot_0"
  return idx2label

# %%
def save_data(df_dogs, path_df_dogs, X, path_X_images):
  '''
  Save data on disk : df_dogs & X images

  example : save_data(df_dogs, path_df_dogs, X, path_X_images)

  '''
  joblib.dump(df_dogs, path_df_dogs, compress=True)
  print("df_dogs Saved here:\n{}".format(path_df_dogs))
  joblib.dump(X, path_X_images, compress=True)
  print("X Saved here:\n{}".format(path_X_images))

# %%
def predict_breed_from_one_path(path_img, mdl):
  '''
  Predict Breed Name from one image path

  example : breedName = predict_breed_from_one_path(path_img, model)
  '''
  print(path_img)
  img, img_raw = load_prepare_img(path_img)
  y = mdl.predict(img) 
  if y.shape[1] >= 1000:
    breedName = decode_predictions(y, top=3)[0]
    print('VGG-16 : Top 3 :', breedName)
  else:
    print("Probabilities : ", y)
    breedName = find_breed(y, dict_breed)
  print(breedName)
  return breedName, img_raw

  def find_breed(y, dict_breed):
    '''
    Find Breed Name from y output of CNN model
    breed_name = find_breed(y, dict_breed)
    '''
    return dict_breed[np.argmax(y)]

# %%
def evaluate_mdl_scorings(Y_train, Y_train_pred,
                          Y_test, Y_test_pred, 
                          timing_fit=0, timing_pred=0):

    '''
    Take scores from predictions
    V1.1 : 24/11/2019 : add acc test per breed
    '''
    dict_scores = dict()
    
    #calculate over same splits f1_micro mean & std
    #cv_lda

    '''
    f1_splits = []
    # on splits test
    for train_index, test_index in cv_lda.split(enc_lda_y_train):
        f1_splits.append(f1_score(enc_lda_y_train[test_index], 
                                  enc_lda_ypred_train[test_index], 
                                  average='micro'))  
    dict_scores["f1_splits_test"] = np.mean(f1_splits)
    dict_scores["f1_splits_test_std"] = np.std(f1_splits)
    '''
    
    # transform as class number 
    Y_train_pred_num = np.argmax(Y_train_pred, axis=1)
    Y_train_num = np.argmax(Y_train, axis=1)
    Y_test_pred_num = np.argmax(Y_test_pred, axis=1)
    Y_test_num = np.argmax(Y_test, axis=1)

    dict_scores["acc_train"] = accuracy_score(Y_train_num, Y_train_pred_num)

    dict_scores["acc_test"] = accuracy_score(Y_test_num, Y_test_pred_num)

    dict_scores["t_fit"] = timing_fit
    dict_scores["t_pred"] = timing_pred

    # find sort of breed name in Y classes (imagent) vs. X classes 
    # (selection of dogs)
    list_id=[]
    for id_y in np.unique(Y_test_num):
      for num_breed, breed_name in dict_breed.items():
        if breed_name == list_Y_classes[id_y]:
          list_id.append(num_breed)
    # add accuracy per breed
    K_id=0
    for id_class in np.unique(Y_test_num):
      str_dict_entry = "acc_test_{}B_{}".format(len(np.unique(Y_test_num)), list_id[K_id])
      dict_scores[str_dict_entry] = accuracy_score(
          Y_test_num[Y_test_num == id_class], 
          Y_test_pred_num[Y_test_num == id_class])
      K_id += 1
    
    return pd.Series(data = dict_scores)

def add_score(df_results, series_scores, model_name):
    
    df_results_add = pd.DataFrame(data=series_scores, columns=[model_name]).T
    
    if df_results is None: # create table
        print('create df_results')
        df_results = df_results_add.copy()
    else: # update or add line
        try:
            # ligne existe alors on efface l'ancienne ligne  ?
            df_results = df_results.drop(index=model_name)                                
            print('update line')
        except:
            # n'existe pas
            print('add line')
            
        # on ajoute la ligne
        df_results = df_results.append(df_results_add)
        
    return df_results

# %% [markdown]
# #### plot_history

# %%
def plot_history(history, my_title=None):
  # plot results at each iterations
  fig = plt.figure(figsize=(12, 8))
  if my_title is not None:
    fig.suptitle(my_title, fontsize=18)
  ax1 = fig.add_subplot(2,2,1)
  ax1.plot(range(0, len(history["acc"])), 
          history["acc"], 'o-')
  ax1.set_xlabel("epochs [-]")
  ax1.set_ylabel("accuracy [-]")
  ax2 = fig.add_subplot(2,2,2)
  ax2.set_xlabel("epochs [-]")
  ax2.set_ylabel("acc test [-]")
  ax2.plot(range(0, len(history['val_acc'])), 
          history["val_acc"], 'ro-')
  ax3 = fig.add_subplot(2,2,3)
  ax3.set_xlabel("epochs [-]")
  ax3.set_ylabel("loss [-]")
  ax3.plot(range(0, len(history['loss'])), 
          history["loss"], 'o-')

  ax4 = fig.add_subplot(2,2,4)
  ax4.set_xlabel("epochs [-]")
  ax4.set_ylabel("val_loss [-]")
  ax4.plot(range(0, len(history['val_loss'])), 
          history["val_loss"], 'ro-')

# %% [markdown]
# ## Data importation

# %% [markdown]
# ### Load images of dogs from different folders

# %%
force_import = False # only from disk or memory
df_dogs = None # from disk

# %%
# import data from disk images & save them into memory and DISK !
df_dogs, X, dict_breed = import_data(paths_images_all_breeds, 
                                     force_import=force_import, 
                                     path_train_list=path_train_list)
# check
print("Image matrix size : ", X.shape)
df_dogs.head()
# Out:
# Loading from disk df_dogs...
# Loading from disk X images...
# Image matrix size :  (2097, 224, 224, 3)
#              filename                                               path  \
# 0  n02107683_1175.jpg  /content/drive/My Drive/OpenClassRooms/IML_Pro...
# 1  n02107683_1248.jpg  /content/drive/My Drive/OpenClassRooms/IML_Pro...
# 2  n02107683_1244.jpg  /content/drive/My Drive/OpenClassRooms/IML_Pro...
# 3  n02107683_1003.jpg  /content/drive/My Drive/OpenClassRooms/IML_Pro...
# 4  n02107683_1076.jpg  /content/drive/My Drive/OpenClassRooms/IML_Pro...
#
#                   breed class  Train
# 0  Bernese_mountain_dog     0  False
# 1  Bernese_mountain_dog     0   True
# 2  Bernese_mountain_dog     0   True
# 3  Bernese_mountain_dog     0  False
# 4  Bernese_mountain_dog     0  False

# %%
# Categorical bar plot with train/test
fig = plt.figure(figsize=(9, 6))
plt.title("Dog image numbers by Breed and by train/test set")
ax = sns.countplot(y="breed", hue="Train", data=df_dogs)

# %% [markdown]
# ## Keras Neural Network from scratch
#
# Just the first part : Neural Network Structure before fitting process

# %% [markdown]
# ### Features

# %%
nb_breeds
# Out:
# 3

# %%
X_train, X_test, Y_train, Y_test, lb = create_separate_features(df_dogs,
  X, list_X_classes=np.array(range(nb_breeds)))
print("X_train ",X_train.shape)
print("X_test ",X_test.shape)
print("Y_train ",Y_train.shape)
print("Y_test ",Y_test.shape)
# Out:
# X_train  (300, 224, 224, 3)
# X_test  (359, 224, 224, 3)
# Y_train  (300, 3)
# Y_test  (359, 3)

# %% [markdown]
# #### Loop over nb conv filters / 50 nodes FC / init Glorot uniform fixed seed (3 runs)
#
# Output layer is fixed to 50.

# %% [markdown]
# ##### Test one shot

# %%
# initializers 
init_he_n = keras.initializers.he_normal(seed=0)
init_glorot_u = keras.initializers.glorot_uniform(seed=0)
# Hyper-parameters
lr = 3e-8
decay = 1e-6
momentum = 0.9
nesterov = True 
nb_filters = 64 # Conv2D layers
nb_nodes = 50 # first FC layer
conv_init = init_glorot_u # Conv2D layers
dens_init = init_glorot_u # first FC layer
out_init = init_glorot_u # output FC layer
# Fitting parameters
epochs = 100
batch_size = None
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', 
                                   verbose=1, patience=10,
                                   restore_best_weights=True)
# Model creation
my_VGG16_03 = Sequential()  # Création d'un réseau de neurones vide 
my_VGG16_03.name = 'my_VGG16_03_gu_early'
# Ajout de la première couche de convolution, suivie d'une couche ReLU
my_VGG16_03.add(Conv2D(nb_filters, kernel_size=3, strides=1, 
                       input_shape=(224, 224, 3),
                       padding='same', activation='relu',
                       kernel_initializer=conv_init))
my_VGG16_03.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))) # test
# Ajout de la deuxième couche de convolution, suivie  d'une couche ReLU
my_VGG16_03.add(Conv2D(nb_filters, kernel_size=3, strides=1, padding='same', 
                       activation='relu',
                       kernel_initializer=conv_init))

# Ajout de la première couche de pooling
my_VGG16_03.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))) # test
my_VGG16_03.add(Flatten())  # Conversion des matrices 3D en vecteur 1D

# Ajout de la première couche fully-connected, suivie d'une couche ReLU
my_VGG16_03.add(Dense(nb_nodes, activation='relu',
                  kernel_initializer=dens_init))

# Ajout de la dernière couche fully-connected qui permet de classifier
my_VGG16_03.add(Dense(nb_breeds, activation='softmax',
                kernel_initializer=out_init))
print(my_VGG16_03.summary())

# optimizer
sgd_2 = optimizers.SGD(lr=lr, decay=decay, momentum=momentum, nesterov=nesterov) 
# compile model
my_VGG16_03.compile(loss="categorical_crossentropy", optimizer=sgd_2, 
                 metrics=["accuracy"])

# fitting
t_fit_0 = time.time()
model_info_3 = my_VGG16_03.fit(X_train, Y_train, epochs=epochs, 
                             batch_size=batch_size, verbose=2,
                             validation_data=(X_test, Y_test),
                             callbacks=[es])
t_fit_1 = time.time()
print("Timing: ", t_fit_1 - t_fit_0)

# plot results at each iterations
plot_history(model_info_3.history)
# Out:
# Model: "my_VGG16_03_gu_early"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 200704)            0
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                10035250
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 10,074,123
# Trainable params: 10,074,123
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 300 samples, validate on 359 samples
# Epoch 1/100
#  - 2s - loss: 7.5525 - acc: 0.3600 - val_loss: 8.2205 - val_acc: 0.3064
# Epoch 2/100
#  - 2s - loss: 7.0101 - acc: 0.3567 - val_loss: 7.6358 - val_acc: 0.2953
# Epoch 3/100
#  - 2s - loss: 6.4792 - acc: 0.3767 - val_loss: 7.1579 - val_acc: 0.3175
# Epoch 4/100
#  - 2s - loss: 6.0295 - acc: 0.3933 - val_loss: 6.8819 - val_acc: 0.3231
# Epoch 5/100
#  - 2s - loss: 5.7914 - acc: 0.3967 - val_loss: 6.7213 - val_acc: 0.3315
# Epoch 6/100
#  - 2s - loss: 5.5115 - acc: 0.3900 - val_loss: 6.5899 - val_acc: 0.3343
# Epoch 7/100
#  - 2s - loss: 5.2596 - acc: 0.4133 - val_loss: 6.4555 - val_acc: 0.3259
# Epoch 8/100
#  - 2s - loss: 4.9977 - acc: 0.4200 - val_loss: 6.3430 - val_acc: 0.3370
# Epoch 9/100
#  - 2s - loss: 4.7455 - acc: 0.4200 - val_loss: 6.2307 - val_acc: 0.3315
# Epoch 10/100
#  - 2s - loss: 4.5185 - acc: 0.4467 - val_loss: 6.0366 - val_acc: 0.3343
# Epoch 11/100
#  - 2s - loss: 4.3344 - acc: 0.4400 - val_loss: 5.8971 - val_acc: 0.3315
# Epoch 12/100
#  - 2s - loss: 4.1607 - acc: 0.4367 - val_loss: 5.8606 - val_acc: 0.3510
# Epoch 13/100
#  - 2s - loss: 4.0125 - acc: 0.4533 - val_loss: 5.7471 - val_acc: 0.3510
# Epoch 14/100
#  - 2s - loss: 3.8837 - acc: 0.4600 - val_loss: 5.6911 - val_acc: 0.3510
# Epoch 15/100
#  - 2s - loss: 3.7881 - acc: 0.4567 - val_loss: 5.5998 - val_acc: 0.3510
# Epoch 16/100
#  - 2s - loss: 3.6946 - acc: 0.4833 - val_loss: 5.4993 - val_acc: 0.3621
# Epoch 17/100
#  - 2s - loss: 3.5652 - acc: 0.4867 - val_loss: 5.5273 - val_acc: 0.3510
# Epoch 18/100
#  - 2s - loss: 3.4808 - acc: 0.4933 - val_loss: 5.4705 - val_acc: 0.3593
# Epoch 19/100
#  - 2s - loss: 3.3739 - acc: 0.4900 - val_loss: 5.3706 - val_acc: 0.3621
# Epoch 20/100
#  - 2s - loss: 3.2931 - acc: 0.5000 - val_loss: 5.2962 - val_acc: 0.3593
# Epoch 21/100
#  - 2s - loss: 3.2119 - acc: 0.5033 - val_loss: 5.2785 - val_acc: 0.3565
# Epoch 22/100
#  - 2s - loss: 3.1207 - acc: 0.5000 - val_loss: 5.2192 - val_acc: 0.3649
# Epoch 23/100
#  - 2s - loss: 3.0438 - acc: 0.5133 - val_loss: 5.1889 - val_acc: 0.3677
# Epoch 24/100
#  - 2s - loss: 2.9740 - acc: 0.5033 - val_loss: 5.1368 - val_acc: 0.3677
# Epoch 25/100
#  - 2s - loss: 2.8935 - acc: 0.5167 - val_loss: 5.0557 - val_acc: 0.3565
# Epoch 26/100
#  - 2s - loss: 2.8101 - acc: 0.5233 - val_loss: 5.0803 - val_acc: 0.3649
# Epoch 27/100
#  - 2s - loss: 2.7449 - acc: 0.5333 - val_loss: 5.0336 - val_acc: 0.3649
# Epoch 28/100
#  - 2s - loss: 2.6911 - acc: 0.5600 - val_loss: 4.9848 - val_acc: 0.3621
# Epoch 29/100
#  - 2s - loss: 2.6093 - acc: 0.5533 - val_loss: 4.8698 - val_acc: 0.3705
# Epoch 30/100
#  - 2s - loss: 2.5594 - acc: 0.5433 - val_loss: 4.8673 - val_acc: 0.3733
# Epoch 31/100
#  - 2s - loss: 2.4795 - acc: 0.5667 - val_loss: 4.8796 - val_acc: 0.3760
# Epoch 32/100
#  - 2s - loss: 2.4290 - acc: 0.5600 - val_loss: 4.8292 - val_acc: 0.3677
# Epoch 33/100
#  - 2s - loss: 2.3653 - acc: 0.5700 - val_loss: 4.7798 - val_acc: 0.3705
# Epoch 34/100
#  - 2s - loss: 2.3149 - acc: 0.5733 - val_loss: 4.7655 - val_acc: 0.3733
# Epoch 35/100
#  - 2s - loss: 2.2660 - acc: 0.5667 - val_loss: 4.7770 - val_acc: 0.3900
# Epoch 36/100
#  - 2s - loss: 2.2169 - acc: 0.5767 - val_loss: 4.7809 - val_acc: 0.3872
# Epoch 37/100
#  - 2s - loss: 2.1741 - acc: 0.5833 - val_loss: 4.7597 - val_acc: 0.3872
# Epoch 38/100
#  - 2s - loss: 2.1248 - acc: 0.5833 - val_loss: 4.7194 - val_acc: 0.3788
# Epoch 39/100
#  - 2s - loss: 2.0958 - acc: 0.6033 - val_loss: 4.6918 - val_acc: 0.3872
# Epoch 40/100
#  - 2s - loss: 2.0519 - acc: 0.6067 - val_loss: 4.7221 - val_acc: 0.3900
# Epoch 41/100
#  - 2s - loss: 2.0069 - acc: 0.5933 - val_loss: 4.6843 - val_acc: 0.3928
# Epoch 42/100
#  - 2s - loss: 1.9709 - acc: 0.6167 - val_loss: 4.6942 - val_acc: 0.3900
# Epoch 43/100
#  - 2s - loss: 1.9436 - acc: 0.6200 - val_loss: 4.6683 - val_acc: 0.3900
# Epoch 44/100
#  - 2s - loss: 1.9065 - acc: 0.6333 - val_loss: 4.6666 - val_acc: 0.3928
# Epoch 45/100
#  - 2s - loss: 1.8746 - acc: 0.6300 - val_loss: 4.6396 - val_acc: 0.3928
# Epoch 46/100
#  - 2s - loss: 1.8428 - acc: 0.6400 - val_loss: 4.6263 - val_acc: 0.3955
# Epoch 47/100
#  - 2s - loss: 1.8123 - acc: 0.6467 - val_loss: 4.6479 - val_acc: 0.3928
# Epoch 48/100
#  - 2s - loss: 1.7973 - acc: 0.6467 - val_loss: 4.6547 - val_acc: 0.3928
# Epoch 49/100
#  - 2s - loss: 1.7531 - acc: 0.6633 - val_loss: 4.5946 - val_acc: 0.4011
# Epoch 50/100
#  - 2s - loss: 1.7369 - acc: 0.6633 - val_loss: 4.5825 - val_acc: 0.4067
# Epoch 51/100
#  - 2s - loss: 1.7110 - acc: 0.6600 - val_loss: 4.6128 - val_acc: 0.4011
# Epoch 52/100
#  - 2s - loss: 1.6743 - acc: 0.6800 - val_loss: 4.5881 - val_acc: 0.4011
# Epoch 53/100
#  - 2s - loss: 1.6441 - acc: 0.6933 - val_loss: 4.5951 - val_acc: 0.4039
# Epoch 54/100
#  - 2s - loss: 1.6238 - acc: 0.6867 - val_loss: 4.5917 - val_acc: 0.4039
# Epoch 55/100
#  - 2s - loss: 1.6006 - acc: 0.6800 - val_loss: 4.5904 - val_acc: 0.4039
# Epoch 56/100
#  - 2s - loss: 1.5738 - acc: 0.6933 - val_loss: 4.5354 - val_acc: 0.4067
# Epoch 57/100
#  - 2s - loss: 1.5535 - acc: 0.7000 - val_loss: 4.5280 - val_acc: 0.4067
# Epoch 58/100
#  - 2s - loss: 1.5249 - acc: 0.7133 - val_loss: 4.5517 - val_acc: 0.4095
# Epoch 59/100
#  - 2s - loss: 1.5015 - acc: 0.7167 - val_loss: 4.5354 - val_acc: 0.4095
# Epoch 60/100
#  - 2s - loss: 1.4766 - acc: 0.7100 - val_loss: 4.5334 - val_acc: 0.4067
# Epoch 61/100
#  - 2s - loss: 1.4449 - acc: 0.7167 - val_loss: 4.5070 - val_acc: 0.4011
# Epoch 62/100
#  - 2s - loss: 1.4257 - acc: 0.7300 - val_loss: 4.5128 - val_acc: 0.3900
# Epoch 63/100
#  - 2s - loss: 1.3996 - acc: 0.7300 - val_loss: 4.5331 - val_acc: 0.4039
# Epoch 64/100
#  - 2s - loss: 1.3787 - acc: 0.7200 - val_loss: 4.5283 - val_acc: 0.4039
# Epoch 65/100
#  - 2s - loss: 1.3572 - acc: 0.7367 - val_loss: 4.5062 - val_acc: 0.3983
# Epoch 66/100
#  - 2s - loss: 1.3342 - acc: 0.7400 - val_loss: 4.5037 - val_acc: 0.3983
# Epoch 67/100
#  - 2s - loss: 1.3154 - acc: 0.7433 - val_loss: 4.4955 - val_acc: 0.3983
# Epoch 68/100
#  - 2s - loss: 1.2960 - acc: 0.7467 - val_loss: 4.4904 - val_acc: 0.3983
# Epoch 69/100
#  - 2s - loss: 1.2765 - acc: 0.7433 - val_loss: 4.5094 - val_acc: 0.3928
# Epoch 70/100
#  - 2s - loss: 1.2551 - acc: 0.7467 - val_loss: 4.4798 - val_acc: 0.3983
# Epoch 71/100
#  - 2s - loss: 1.2390 - acc: 0.7567 - val_loss: 4.4662 - val_acc: 0.3928
# Epoch 72/100
#  - 2s - loss: 1.2305 - acc: 0.7600 - val_loss: 4.4702 - val_acc: 0.3955
# Epoch 73/100
#  - 2s - loss: 1.2127 - acc: 0.7533 - val_loss: 4.4913 - val_acc: 0.3872
# Epoch 74/100
#  - 2s - loss: 1.1873 - acc: 0.7600 - val_loss: 4.4712 - val_acc: 0.3983
# Epoch 75/100
#  - 2s - loss: 1.1711 - acc: 0.7700 - val_loss: 4.4611 - val_acc: 0.3928
# Epoch 76/100
#  - 2s - loss: 1.1578 - acc: 0.7733 - val_loss: 4.4582 - val_acc: 0.3928
# Epoch 77/100
#  - 2s - loss: 1.1401 - acc: 0.7833 - val_loss: 4.4668 - val_acc: 0.3928
# Epoch 78/100
#  - 2s - loss: 1.1296 - acc: 0.7767 - val_loss: 4.4606 - val_acc: 0.3900
# Epoch 79/100
#  - 2s - loss: 1.1152 - acc: 0.7767 - val_loss: 4.4721 - val_acc: 0.3928
# Epoch 80/100
#  - 2s - loss: 1.1004 - acc: 0.7867 - val_loss: 4.4614 - val_acc: 0.3983
# Epoch 81/100
#  - 2s - loss: 1.0856 - acc: 0.7833 - val_loss: 4.4550 - val_acc: 0.3983
# Epoch 82/100
#  - 2s - loss: 1.0745 - acc: 0.7900 - val_loss: 4.4552 - val_acc: 0.3928
# Epoch 83/100
#  - 2s - loss: 1.0611 - acc: 0.7933 - val_loss: 4.4505 - val_acc: 0.3983
# Epoch 84/100
#  - 2s - loss: 1.0487 - acc: 0.8000 - val_loss: 4.4395 - val_acc: 0.3928
# Epoch 85/100
#  - 2s - loss: 1.0376 - acc: 0.7967 - val_loss: 4.4346 - val_acc: 0.3928
# Epoch 86/100
#  - 2s - loss: 1.0256 - acc: 0.8067 - val_loss: 4.4361 - val_acc: 0.3928
# Epoch 87/100
#  - 2s - loss: 1.0140 - acc: 0.8067 - val_loss: 4.4348 - val_acc: 0.3928
# Epoch 88/100
#  - 2s - loss: 1.0033 - acc: 0.8167 - val_loss: 4.4353 - val_acc: 0.3955
# Epoch 89/100
#  - 2s - loss: 0.9924 - acc: 0.8133 - val_loss: 4.4354 - val_acc: 0.3955
# Epoch 90/100
#  - 2s - loss: 0.9814 - acc: 0.8200 - val_loss: 4.4198 - val_acc: 0.3900
# Epoch 91/100
#  - 2s - loss: 0.9727 - acc: 0.8267 - val_loss: 4.4248 - val_acc: 0.3900
# Epoch 92/100
#  - 2s - loss: 0.9629 - acc: 0.8300 - val_loss: 4.4168 - val_acc: 0.3872
# Epoch 93/100
#  - 2s - loss: 0.9501 - acc: 0.8333 - val_loss: 4.4232 - val_acc: 0.3900
# Epoch 94/100
#  - 2s - loss: 0.9411 - acc: 0.8300 - val_loss: 4.4260 - val_acc: 0.3872
# Epoch 95/100
#  - 2s - loss: 0.9320 - acc: 0.8433 - val_loss: 4.4180 - val_acc: 0.3900
# Epoch 96/100
#  - 2s - loss: 0.9220 - acc: 0.8300 - val_loss: 4.4321 - val_acc: 0.3844
# Epoch 97/100
#  - 2s - loss: 0.9127 - acc: 0.8433 - val_loss: 4.4076 - val_acc: 0.3955
# Epoch 98/100
#  - 2s - loss: 0.9048 - acc: 0.8433 - val_loss: 4.4120 - val_acc: 0.3900
# Epoch 99/100
#  - 2s - loss: 0.8948 - acc: 0.8467 - val_loss: 4.4299 - val_acc: 0.3844
# Epoch 100/100
#  - 2s - loss: 0.8874 - acc: 0.8500 - val_loss: 4.4306 - val_acc: 0.3900
# Timing:  186.7014570236206

# %%
name_df_res = 'df_res_filters_gu0_50nod'
print(name_df_res + " Saved here:\n" + path_data + name_df_res + '.pkl')
# Out:
# df_res_filters_gu0_50nod Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/df_res_filters_gu0_50nod.pkl

# %% [markdown]
# ##### Loop over filters 64 128 256

# %%
name_df_res = 'df_res_filters_gu0_50nod'

# initializers 
init_he_n = keras.initializers.he_normal(seed=0)
init_glorot_u = keras.initializers.glorot_uniform(seed=0)
# Hyper-parameters
lr = 3e-8
decay = 1e-6
momentum = 0.9
nesterov = True 
#nb_filters = 320 # Conv2D layers
nb_nodes = 50 # first FC layer
conv_init = init_glorot_u # Conv2D layers
dens_init = init_glorot_u # First FC Dense layer
out_init = init_glorot_u # Output FC Dense layer

# Fitting parameters
epochs = 150
batch_size = None
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', 
                                   verbose=1, patience=30,
                                   restore_best_weights=True)
# init output variables
df_res = None
#list_nb_filters = []
#list_nb_try = []

# loop on nb filter to check if accuracy is better and memory not saturated
for nb_filters in [64, 128, 256, 320]:
  print("nb_filters: ", nb_filters)
  for nb_try in range(0, 3):
    print("nb_try: ", nb_try)
    #list_nb_filters.append(nb_filters)
    #list_nb_try.append(nb_try)

    # Model creation
    my_VGG16_03 = Sequential()  # Création d'un réseau de neurones vide 
    my_VGG16_03.name = 'my_VGG16_03_{}filt_gu0_50nod_{}'.format(nb_filters, 
                                                               nb_try)

    # Ajout de la première couche de convolution, suivie d'une couche ReLU
    my_VGG16_03.add(Conv2D(nb_filters, kernel_size=3, strides=1, 
                          input_shape=(224, 224, 3),
                          padding='same', activation='relu',
                          kernel_initializer=conv_init))
    my_VGG16_03.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))) # test
    # Ajout de la deuxième couche de convolution, suivie  d'une couche ReLU
    my_VGG16_03.add(Conv2D(nb_filters, kernel_size=3, strides=1, padding='same', 
                          activation='relu',
                          kernel_initializer=conv_init))

    # Ajout de la première couche de pooling
    my_VGG16_03.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))) # test
    my_VGG16_03.add(Flatten())  # Conversion des matrices 3D en vecteur 1D

    # Ajout de la première couche fully-connected, suivie d'une couche ReLU
    my_VGG16_03.add(Dense(nb_nodes, activation='relu',
                      kernel_initializer=dens_init))

    # Ajout de la dernière couche fully-connected qui permet de classifier
    my_VGG16_03.add(Dense(nb_breeds, activation='softmax',
                    kernel_initializer=out_init))
    print(my_VGG16_03.summary())

    # optimizer
    sgd_2 = optimizers.SGD(lr=lr, decay=decay, momentum=momentum, 
                           nesterov=nesterov) 
    # compile model
    my_VGG16_03.compile(loss="categorical_crossentropy", optimizer=sgd_2, 
                    metrics=["accuracy"])

    t_fit_0 = time.time()
    # fitting
    model_info_3 = my_VGG16_03.fit(X_train, Y_train, epochs=epochs, 
                                batch_size=batch_size, verbose=2,
                                validation_data=(X_test, Y_test),
                                callbacks=[es])
    t_fit_1 = time.time()
    print("Timing: ", t_fit_1 - t_fit_0)

    # save : model info
    joblib.dump(model_info_3.history, 
                path_data + 'hist_' + my_VGG16_03.name + '.pkl'.\
                format(nb_filters, nb_try), compress=True)
    print("model_info_3 history Saved here:\n{}".\
          format(path_data + 'hist_' + my_VGG16_03.name + '.pkl'.\
                format(nb_filters, nb_try)))

    # plot results at each iterations
    plot_history(model_info_3.history)

    #  save
    my_VGG16_03.save(path_data + my_VGG16_03.name + '.h5')

    # predict as binary labels
    t_pred_0 = time.time()
    Y_train_pred = my_VGG16_03.predict(X_train)
    t_pred_1 = time.time()
    # predict as binary labels
    t_pred_2 = time.time()
    Y_test_pred = my_VGG16_03.predict(X_test)
    t_pred_3 = time.time()

    # prepare results
    series_scores = evaluate_mdl_scorings(Y_train, Y_train_pred, 
                                      Y_test, Y_test_pred, 
      timing_fit=t_fit_1 - t_fit_0, 
      timing_pred=t_pred_3-t_pred_2+t_pred_1-t_pred_0)
    df_res = add_score(df_res, series_scores, my_VGG16_03.name)
    df_res.at[my_VGG16_03.name,"nb_filters"] = nb_filters
    df_res.at[my_VGG16_03.name,"nb_try"] = nb_try
    # save results
    joblib.dump(df_res, path_data + name_df_res + '.pkl', compress=True)
    print(name_df_res + " Saved here:\n" + path_data + name_df_res + '.pkl')

# save results
joblib.dump(df_res, path_data + name_df_res + '.pkl', compress=True)
print(name_df_res + " Saved here:\n" + path_data + name_df_res + '.pkl')
    
exec(name_df_res+'=df_res.copy()')
exec(name_df_res)
# Out:
# nb_filters:  64
# nb_try:  0
# Model: "my_VGG16_03_64filt_gu0_50nod_0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 200704)            0
# _________________________________________________________________
# dense_11 (Dense)             (None, 50)                10035250
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 10,074,123
# Trainable params: 10,074,123
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 300 samples, validate on 359 samples
# Epoch 1/150
#  - 2s - loss: 7.5573 - acc: 0.3600 - val_loss: 8.1792 - val_acc: 0.3092
# Epoch 2/150
#  - 2s - loss: 7.0006 - acc: 0.3700 - val_loss: 7.6703 - val_acc: 0.2925
# Epoch 3/150
#  - 2s - loss: 6.5198 - acc: 0.3600 - val_loss: 7.1905 - val_acc: 0.3092
# Epoch 4/150
#  - 2s - loss: 6.0586 - acc: 0.3833 - val_loss: 7.0049 - val_acc: 0.3203
# Epoch 5/150
#  - 2s - loss: 5.7823 - acc: 0.3967 - val_loss: 6.8512 - val_acc: 0.3259
# Epoch 6/150
#  - 2s - loss: 5.5315 - acc: 0.4033 - val_loss: 6.6833 - val_acc: 0.3259
# Epoch 7/150
#  - 2s - loss: 5.2934 - acc: 0.4167 - val_loss: 6.4905 - val_acc: 0.3454
# Epoch 8/150
#  - 2s - loss: 5.0355 - acc: 0.4100 - val_loss: 6.3491 - val_acc: 0.3426
# Epoch 9/150
#  - 2s - loss: 4.7796 - acc: 0.4167 - val_loss: 6.1976 - val_acc: 0.3370
# Epoch 10/150
#  - 2s - loss: 4.5140 - acc: 0.4333 - val_loss: 6.0907 - val_acc: 0.3398
# Epoch 11/150
#  - 2s - loss: 4.3119 - acc: 0.4500 - val_loss: 5.8928 - val_acc: 0.3426
# Epoch 12/150
#  - 2s - loss: 4.1524 - acc: 0.4333 - val_loss: 5.7941 - val_acc: 0.3426
# Epoch 13/150
#  - 2s - loss: 3.9964 - acc: 0.4533 - val_loss: 5.7751 - val_acc: 0.3426
# Epoch 14/150
#  - 2s - loss: 3.8878 - acc: 0.4567 - val_loss: 5.7121 - val_acc: 0.3510
# Epoch 15/150
#  - 2s - loss: 3.7590 - acc: 0.4867 - val_loss: 5.5867 - val_acc: 0.3565
# Epoch 16/150
#  - 2s - loss: 3.6553 - acc: 0.4767 - val_loss: 5.5483 - val_acc: 0.3621
# Epoch 17/150
#  - 2s - loss: 3.5444 - acc: 0.4967 - val_loss: 5.5020 - val_acc: 0.3649
# Epoch 18/150
#  - 2s - loss: 3.4431 - acc: 0.5000 - val_loss: 5.4648 - val_acc: 0.3677
# Epoch 19/150
#  - 2s - loss: 3.3493 - acc: 0.4967 - val_loss: 5.3886 - val_acc: 0.3733
# Epoch 20/150
#  - 2s - loss: 3.2672 - acc: 0.5100 - val_loss: 5.3731 - val_acc: 0.3760
# Epoch 21/150
#  - 2s - loss: 3.1747 - acc: 0.5133 - val_loss: 5.3450 - val_acc: 0.3788
# Epoch 22/150
#  - 2s - loss: 3.0877 - acc: 0.5133 - val_loss: 5.2622 - val_acc: 0.3733
# Epoch 23/150
#  - 2s - loss: 3.0023 - acc: 0.5167 - val_loss: 5.2292 - val_acc: 0.3760
# Epoch 24/150
#  - 2s - loss: 2.9228 - acc: 0.5133 - val_loss: 5.2171 - val_acc: 0.3733
# Epoch 25/150
#  - 2s - loss: 2.8434 - acc: 0.5300 - val_loss: 5.1531 - val_acc: 0.3760
# Epoch 26/150
#  - 2s - loss: 2.7712 - acc: 0.5267 - val_loss: 5.1250 - val_acc: 0.3788
# Epoch 27/150
#  - 2s - loss: 2.7072 - acc: 0.5400 - val_loss: 5.1021 - val_acc: 0.3788
# Epoch 28/150
#  - 2s - loss: 2.6350 - acc: 0.5400 - val_loss: 5.0604 - val_acc: 0.3816
# Epoch 29/150
#  - 2s - loss: 2.5774 - acc: 0.5367 - val_loss: 5.0320 - val_acc: 0.3872
# Epoch 30/150
#  - 2s - loss: 2.5191 - acc: 0.5400 - val_loss: 5.0317 - val_acc: 0.3733
# Epoch 31/150
#  - 2s - loss: 2.4677 - acc: 0.5567 - val_loss: 4.9889 - val_acc: 0.3816
# Epoch 32/150
#  - 2s - loss: 2.4033 - acc: 0.5533 - val_loss: 4.9189 - val_acc: 0.3760
# Epoch 33/150
#  - 2s - loss: 2.3453 - acc: 0.5667 - val_loss: 4.9134 - val_acc: 0.3733
# Epoch 34/150
#  - 2s - loss: 2.2953 - acc: 0.5533 - val_loss: 4.9266 - val_acc: 0.3733
# Epoch 35/150
#  - 2s - loss: 2.2491 - acc: 0.5600 - val_loss: 4.8492 - val_acc: 0.3872
# Epoch 36/150
#  - 2s - loss: 2.2146 - acc: 0.5667 - val_loss: 4.8152 - val_acc: 0.3844
# Epoch 37/150
#  - 2s - loss: 2.1594 - acc: 0.5833 - val_loss: 4.8611 - val_acc: 0.3677
# Epoch 38/150
#  - 2s - loss: 2.1138 - acc: 0.5867 - val_loss: 4.8096 - val_acc: 0.3788
# Epoch 39/150
#  - 2s - loss: 2.0701 - acc: 0.5967 - val_loss: 4.7927 - val_acc: 0.3760
# Epoch 40/150
#  - 2s - loss: 2.0388 - acc: 0.6033 - val_loss: 4.7793 - val_acc: 0.3816
# Epoch 41/150
#  - 2s - loss: 2.0010 - acc: 0.6133 - val_loss: 4.7650 - val_acc: 0.3788
# Epoch 42/150
#  - 2s - loss: 1.9724 - acc: 0.6200 - val_loss: 4.7649 - val_acc: 0.3844
# Epoch 43/150
#  - 2s - loss: 1.9424 - acc: 0.6167 - val_loss: 4.7774 - val_acc: 0.3788
# Epoch 44/150
#  - 2s - loss: 1.9060 - acc: 0.6333 - val_loss: 4.7414 - val_acc: 0.3816
# Epoch 45/150
#  - 2s - loss: 1.8759 - acc: 0.6467 - val_loss: 4.7388 - val_acc: 0.3760
# Epoch 46/150
#  - 2s - loss: 1.8457 - acc: 0.6467 - val_loss: 4.7332 - val_acc: 0.3760
# Epoch 47/150
#  - 2s - loss: 1.8277 - acc: 0.6633 - val_loss: 4.7213 - val_acc: 0.3816
# Epoch 48/150
#  - 2s - loss: 1.7920 - acc: 0.6600 - val_loss: 4.7247 - val_acc: 0.3788
# Epoch 49/150
#  - 2s - loss: 1.7558 - acc: 0.6567 - val_loss: 4.7057 - val_acc: 0.3844
# Epoch 50/150
#  - 2s - loss: 1.7355 - acc: 0.6700 - val_loss: 4.6976 - val_acc: 0.3872
# Epoch 51/150
#  - 2s - loss: 1.7165 - acc: 0.6633 - val_loss: 4.7079 - val_acc: 0.3816
# Epoch 52/150
#  - 2s - loss: 1.6835 - acc: 0.6900 - val_loss: 4.6624 - val_acc: 0.3844
# Epoch 53/150
#  - 2s - loss: 1.6509 - acc: 0.6933 - val_loss: 4.6650 - val_acc: 0.3760
# Epoch 54/150
#  - 2s - loss: 1.6248 - acc: 0.7000 - val_loss: 4.6647 - val_acc: 0.3816
# Epoch 55/150
#  - 2s - loss: 1.6006 - acc: 0.6967 - val_loss: 4.6427 - val_acc: 0.3816
# Epoch 56/150
#  - 2s - loss: 1.5764 - acc: 0.7067 - val_loss: 4.6490 - val_acc: 0.3844
# Epoch 57/150
#  - 2s - loss: 1.5490 - acc: 0.7167 - val_loss: 4.6499 - val_acc: 0.3900
# Epoch 58/150
#  - 2s - loss: 1.5266 - acc: 0.7233 - val_loss: 4.6426 - val_acc: 0.3872
# Epoch 59/150
#  - 2s - loss: 1.5061 - acc: 0.7333 - val_loss: 4.6383 - val_acc: 0.3900
# Epoch 60/150
#  - 2s - loss: 1.4841 - acc: 0.7333 - val_loss: 4.6352 - val_acc: 0.3872
# Epoch 61/150
#  - 2s - loss: 1.4612 - acc: 0.7300 - val_loss: 4.6227 - val_acc: 0.3844
# Epoch 62/150
#  - 2s - loss: 1.4378 - acc: 0.7267 - val_loss: 4.6252 - val_acc: 0.3872
# Epoch 63/150
#  - 2s - loss: 1.4229 - acc: 0.7300 - val_loss: 4.6166 - val_acc: 0.3872
# Epoch 64/150
#  - 2s - loss: 1.4015 - acc: 0.7433 - val_loss: 4.5964 - val_acc: 0.3872
# Epoch 65/150
#  - 2s - loss: 1.3835 - acc: 0.7367 - val_loss: 4.6014 - val_acc: 0.3928
# Epoch 66/150
#  - 2s - loss: 1.3591 - acc: 0.7567 - val_loss: 4.6206 - val_acc: 0.3955
# Epoch 67/150
#  - 2s - loss: 1.3412 - acc: 0.7533 - val_loss: 4.5980 - val_acc: 0.3955
# Epoch 68/150
#  - 2s - loss: 1.3238 - acc: 0.7433 - val_loss: 4.5904 - val_acc: 0.3900
# Epoch 69/150
#  - 2s - loss: 1.3060 - acc: 0.7467 - val_loss: 4.5959 - val_acc: 0.3955
# Epoch 70/150
#  - 2s - loss: 1.2965 - acc: 0.7667 - val_loss: 4.6080 - val_acc: 0.3872
# Epoch 71/150
#  - 2s - loss: 1.2779 - acc: 0.7567 - val_loss: 4.5691 - val_acc: 0.3900
# Epoch 72/150
#  - 2s - loss: 1.2486 - acc: 0.7700 - val_loss: 4.6017 - val_acc: 0.3900
# Epoch 73/150
#  - 2s - loss: 1.2338 - acc: 0.7733 - val_loss: 4.5838 - val_acc: 0.3955
# Epoch 74/150
#  - 2s - loss: 1.2149 - acc: 0.7767 - val_loss: 4.5617 - val_acc: 0.3928
# Epoch 75/150
#  - 2s - loss: 1.2010 - acc: 0.7800 - val_loss: 4.5395 - val_acc: 0.3928
# Epoch 76/150
#  - 2s - loss: 1.1858 - acc: 0.7767 - val_loss: 4.5569 - val_acc: 0.3983
# Epoch 77/150
#  - 2s - loss: 1.1683 - acc: 0.7800 - val_loss: 4.5401 - val_acc: 0.3928
# Epoch 78/150
#  - 2s - loss: 1.1546 - acc: 0.7900 - val_loss: 4.5289 - val_acc: 0.3983
# Epoch 79/150
#  - 2s - loss: 1.1409 - acc: 0.7933 - val_loss: 4.5509 - val_acc: 0.3928
# Epoch 80/150
#  - 2s - loss: 1.1273 - acc: 0.7900 - val_loss: 4.5588 - val_acc: 0.3983
# Epoch 81/150
#  - 2s - loss: 1.1128 - acc: 0.7900 - val_loss: 4.5583 - val_acc: 0.3983
# Epoch 82/150
#  - 2s - loss: 1.1016 - acc: 0.7900 - val_loss: 4.5422 - val_acc: 0.3900
# Epoch 83/150
#  - 2s - loss: 1.0890 - acc: 0.8000 - val_loss: 4.5390 - val_acc: 0.3955
# Epoch 84/150
#  - 2s - loss: 1.0757 - acc: 0.7967 - val_loss: 4.5176 - val_acc: 0.3928
# Epoch 85/150
#  - 2s - loss: 1.0682 - acc: 0.8033 - val_loss: 4.5358 - val_acc: 0.3928
# Epoch 86/150
#  - 2s - loss: 1.0521 - acc: 0.8033 - val_loss: 4.5494 - val_acc: 0.3955
# Epoch 87/150
#  - 2s - loss: 1.0416 - acc: 0.8033 - val_loss: 4.5371 - val_acc: 0.3900
# Epoch 88/150
#  - 2s - loss: 1.0297 - acc: 0.8133 - val_loss: 4.5413 - val_acc: 0.3955
# Epoch 89/150
#  - 2s - loss: 1.0200 - acc: 0.8133 - val_loss: 4.5357 - val_acc: 0.3955
# Epoch 90/150
#  - 2s - loss: 1.0108 - acc: 0.8167 - val_loss: 4.5382 - val_acc: 0.3928
# Epoch 91/150
#  - 2s - loss: 1.0031 - acc: 0.8200 - val_loss: 4.5454 - val_acc: 0.3928
# Epoch 92/150
#  - 2s - loss: 0.9930 - acc: 0.8233 - val_loss: 4.5432 - val_acc: 0.3955
# Epoch 93/150
#  - 2s - loss: 0.9832 - acc: 0.8233 - val_loss: 4.5021 - val_acc: 0.3900
# Epoch 94/150
#  - 2s - loss: 0.9716 - acc: 0.8300 - val_loss: 4.5122 - val_acc: 0.4011
# Epoch 95/150
#  - 2s - loss: 0.9645 - acc: 0.8367 - val_loss: 4.5246 - val_acc: 0.3955
# Epoch 96/150
#  - 2s - loss: 0.9523 - acc: 0.8400 - val_loss: 4.4862 - val_acc: 0.3900
# Epoch 97/150
#  - 2s - loss: 0.9460 - acc: 0.8433 - val_loss: 4.4835 - val_acc: 0.3872
# Epoch 98/150
#  - 2s - loss: 0.9369 - acc: 0.8367 - val_loss: 4.5010 - val_acc: 0.3928
# Epoch 99/150
#  - 2s - loss: 0.9295 - acc: 0.8467 - val_loss: 4.4678 - val_acc: 0.3928
# Epoch 100/150
#  - 2s - loss: 0.9204 - acc: 0.8600 - val_loss: 4.4887 - val_acc: 0.3928
# Epoch 101/150
#  - 2s - loss: 0.9076 - acc: 0.8567 - val_loss: 4.4698 - val_acc: 0.3872
# Epoch 102/150
#  - 2s - loss: 0.8976 - acc: 0.8500 - val_loss: 4.4827 - val_acc: 0.3872
# Epoch 103/150
#  - 2s - loss: 0.8919 - acc: 0.8600 - val_loss: 4.4809 - val_acc: 0.3872
# Epoch 104/150
#  - 2s - loss: 0.8824 - acc: 0.8667 - val_loss: 4.4669 - val_acc: 0.3872
# Epoch 105/150
#  - 2s - loss: 0.8754 - acc: 0.8667 - val_loss: 4.4771 - val_acc: 0.3844
# Epoch 106/150
#  - 2s - loss: 0.8675 - acc: 0.8600 - val_loss: 4.4667 - val_acc: 0.3844
# Epoch 107/150
#  - 2s - loss: 0.8580 - acc: 0.8667 - val_loss: 4.4940 - val_acc: 0.3928
# Epoch 108/150
#  - 2s - loss: 0.8509 - acc: 0.8633 - val_loss: 4.4741 - val_acc: 0.3928
# Epoch 109/150
#  - 2s - loss: 0.8447 - acc: 0.8667 - val_loss: 4.4556 - val_acc: 0.3928
# Epoch 110/150
#  - 2s - loss: 0.8354 - acc: 0.8700 - val_loss: 4.4583 - val_acc: 0.3928
# Epoch 111/150
#  - 2s - loss: 0.8306 - acc: 0.8667 - val_loss: 4.4667 - val_acc: 0.3900
# Epoch 112/150
#  - 2s - loss: 0.8240 - acc: 0.8667 - val_loss: 4.4512 - val_acc: 0.3900
# Epoch 113/150
#  - 2s - loss: 0.8151 - acc: 0.8700 - val_loss: 4.4309 - val_acc: 0.3900
# Epoch 114/150
#  - 2s - loss: 0.8099 - acc: 0.8700 - val_loss: 4.4487 - val_acc: 0.3900
# Epoch 115/150
#  - 2s - loss: 0.8031 - acc: 0.8700 - val_loss: 4.4440 - val_acc: 0.3928
# Epoch 116/150
#  - 2s - loss: 0.7973 - acc: 0.8700 - val_loss: 4.4571 - val_acc: 0.3900
# Epoch 117/150
#  - 2s - loss: 0.7886 - acc: 0.8700 - val_loss: 4.4428 - val_acc: 0.3900
# Epoch 118/150
#  - 2s - loss: 0.7842 - acc: 0.8767 - val_loss: 4.4311 - val_acc: 0.3872
# Epoch 119/150
#  - 2s - loss: 0.7792 - acc: 0.8767 - val_loss: 4.4435 - val_acc: 0.3900
# Epoch 120/150
#  - 2s - loss: 0.7716 - acc: 0.8767 - val_loss: 4.4345 - val_acc: 0.3872
# Epoch 121/150
#  - 2s - loss: 0.7667 - acc: 0.8733 - val_loss: 4.4402 - val_acc: 0.3844
# Epoch 122/150
#  - 2s - loss: 0.7604 - acc: 0.8800 - val_loss: 4.4288 - val_acc: 0.3900
# Epoch 123/150
#  - 2s - loss: 0.7541 - acc: 0.8833 - val_loss: 4.4338 - val_acc: 0.3872
# Epoch 124/150
#  - 2s - loss: 0.7490 - acc: 0.8833 - val_loss: 4.4335 - val_acc: 0.3844
# Epoch 125/150
#  - 2s - loss: 0.7451 - acc: 0.8833 - val_loss: 4.4337 - val_acc: 0.3844
# Epoch 126/150
#  - 2s - loss: 0.7409 - acc: 0.8833 - val_loss: 4.4397 - val_acc: 0.3872
# Epoch 127/150
#  - 2s - loss: 0.7380 - acc: 0.8833 - val_loss: 4.4247 - val_acc: 0.3900
# Epoch 128/150
#  - 2s - loss: 0.7291 - acc: 0.8833 - val_loss: 4.4436 - val_acc: 0.3900
# Epoch 129/150
#  - 2s - loss: 0.7251 - acc: 0.8900 - val_loss: 4.4363 - val_acc: 0.3872
# Epoch 130/150
#  - 2s - loss: 0.7196 - acc: 0.8900 - val_loss: 4.4111 - val_acc: 0.3900
# Epoch 131/150
#  - 2s - loss: 0.7164 - acc: 0.8833 - val_loss: 4.4166 - val_acc: 0.3872
# Epoch 132/150
#  - 2s - loss: 0.7111 - acc: 0.8900 - val_loss: 4.4284 - val_acc: 0.3872
# Epoch 133/150
#  - 2s - loss: 0.7070 - acc: 0.8933 - val_loss: 4.4314 - val_acc: 0.3900
# Epoch 134/150
#  - 2s - loss: 0.7028 - acc: 0.8900 - val_loss: 4.4194 - val_acc: 0.3900
# Epoch 135/150
#  - 2s - loss: 0.6969 - acc: 0.8900 - val_loss: 4.4147 - val_acc: 0.3872
# Epoch 136/150
#  - 2s - loss: 0.6937 - acc: 0.8933 - val_loss: 4.4185 - val_acc: 0.3900
# Epoch 137/150
#  - 2s - loss: 0.6903 - acc: 0.8933 - val_loss: 4.4232 - val_acc: 0.3900
# Epoch 138/150
#  - 2s - loss: 0.6853 - acc: 0.8933 - val_loss: 4.4135 - val_acc: 0.3900
# Epoch 139/150
#  - 2s - loss: 0.6823 - acc: 0.8933 - val_loss: 4.4156 - val_acc: 0.3872
# Epoch 140/150
#  - 2s - loss: 0.6779 - acc: 0.8967 - val_loss: 4.3947 - val_acc: 0.4011
# Epoch 141/150
#  - 2s - loss: 0.6753 - acc: 0.9000 - val_loss: 4.4103 - val_acc: 0.3900
# Epoch 142/150
#  - 2s - loss: 0.6702 - acc: 0.8967 - val_loss: 4.4110 - val_acc: 0.3844
# Epoch 143/150
#  - 2s - loss: 0.6672 - acc: 0.9000 - val_loss: 4.4122 - val_acc: 0.3900
# Epoch 144/150
#  - 2s - loss: 0.6647 - acc: 0.8967 - val_loss: 4.4239 - val_acc: 0.3844
# Epoch 145/150
#  - 2s - loss: 0.6611 - acc: 0.9000 - val_loss: 4.3902 - val_acc: 0.3955
# Epoch 146/150
#  - 2s - loss: 0.6568 - acc: 0.9000 - val_loss: 4.3961 - val_acc: 0.3900
# Epoch 147/150
#  - 2s - loss: 0.6535 - acc: 0.9033 - val_loss: 4.4083 - val_acc: 0.3872
# Epoch 148/150
#  - 2s - loss: 0.6496 - acc: 0.9067 - val_loss: 4.3900 - val_acc: 0.3955
# Epoch 149/150
#  - 2s - loss: 0.6481 - acc: 0.9067 - val_loss: 4.3827 - val_acc: 0.3983
# Epoch 150/150
#  - 2s - loss: 0.6423 - acc: 0.9000 - val_loss: 4.4005 - val_acc: 0.3872
# Timing:  278.9676694869995
# model_info_3 history Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/hist_my_VGG16_03_64filt_gu0_50nod_0.pkl
# create df_results
# df_res_filters_gu0_50nod Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/df_res_filters_gu0_50nod.pkl
# nb_try:  1
# Model: "my_VGG16_03_64filt_gu0_50nod_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 200704)            0
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                10035250
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 10,074,123
# Trainable params: 10,074,123
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 300 samples, validate on 359 samples
# Epoch 1/150
#  - 2s - loss: 7.5596 - acc: 0.3700 - val_loss: 8.2432 - val_acc: 0.3064
# Epoch 2/150
#  - 2s - loss: 7.0854 - acc: 0.3633 - val_loss: 7.6629 - val_acc: 0.2953
# Epoch 3/150
#  - 2s - loss: 6.5042 - acc: 0.3600 - val_loss: 7.2061 - val_acc: 0.3064
# Epoch 4/150
#  - 2s - loss: 6.0573 - acc: 0.3933 - val_loss: 6.9053 - val_acc: 0.3231
# Epoch 5/150
#  - 2s - loss: 5.7614 - acc: 0.3867 - val_loss: 6.7632 - val_acc: 0.3259
# Epoch 6/150
#  - 2s - loss: 5.5070 - acc: 0.4100 - val_loss: 6.6495 - val_acc: 0.3259
# Epoch 7/150
#  - 2s - loss: 5.2470 - acc: 0.4167 - val_loss: 6.4870 - val_acc: 0.3398
# Epoch 8/150
#  - 2s - loss: 5.0054 - acc: 0.4133 - val_loss: 6.3154 - val_acc: 0.3370
# Epoch 9/150
#  - 2s - loss: 4.7409 - acc: 0.4300 - val_loss: 6.1569 - val_acc: 0.3538
# Epoch 10/150
#  - 2s - loss: 4.5412 - acc: 0.4300 - val_loss: 5.9646 - val_acc: 0.3593
# Epoch 11/150
#  - 2s - loss: 4.3199 - acc: 0.4467 - val_loss: 5.8893 - val_acc: 0.3482
# Epoch 12/150
#  - 2s - loss: 4.1725 - acc: 0.4467 - val_loss: 5.8147 - val_acc: 0.3482
# Epoch 13/150
#  - 2s - loss: 4.0390 - acc: 0.4600 - val_loss: 5.7303 - val_acc: 0.3538
# Epoch 14/150
#  - 2s - loss: 3.8978 - acc: 0.4667 - val_loss: 5.6151 - val_acc: 0.3510
# Epoch 15/150
#  - 2s - loss: 3.7866 - acc: 0.4800 - val_loss: 5.5758 - val_acc: 0.3565
# Epoch 16/150
#  - 2s - loss: 3.6779 - acc: 0.4867 - val_loss: 5.5247 - val_acc: 0.3593
# Epoch 17/150
#  - 2s - loss: 3.5669 - acc: 0.4933 - val_loss: 5.4773 - val_acc: 0.3565
# Epoch 18/150
#  - 2s - loss: 3.4821 - acc: 0.4933 - val_loss: 5.4656 - val_acc: 0.3538
# Epoch 19/150
#  - 2s - loss: 3.3717 - acc: 0.4933 - val_loss: 5.3478 - val_acc: 0.3677
# Epoch 20/150
#  - 2s - loss: 3.2880 - acc: 0.5067 - val_loss: 5.2931 - val_acc: 0.3621
# Epoch 21/150
#  - 2s - loss: 3.1972 - acc: 0.5000 - val_loss: 5.2714 - val_acc: 0.3593
# Epoch 22/150
#  - 2s - loss: 3.1282 - acc: 0.5067 - val_loss: 5.2159 - val_acc: 0.3621
# Epoch 23/150
#  - 2s - loss: 3.0325 - acc: 0.5100 - val_loss: 5.1860 - val_acc: 0.3593
# Epoch 24/150
#  - 2s - loss: 2.9499 - acc: 0.5200 - val_loss: 5.1476 - val_acc: 0.3593
# Epoch 25/150
#  - 2s - loss: 2.8851 - acc: 0.5200 - val_loss: 5.0863 - val_acc: 0.3593
# Epoch 26/150
#  - 2s - loss: 2.8007 - acc: 0.5400 - val_loss: 5.0275 - val_acc: 0.3621
# Epoch 27/150
#  - 2s - loss: 2.7269 - acc: 0.5400 - val_loss: 5.0366 - val_acc: 0.3621
# Epoch 28/150
#  - 2s - loss: 2.6730 - acc: 0.5467 - val_loss: 4.9881 - val_acc: 0.3621
# Epoch 29/150
#  - 2s - loss: 2.6139 - acc: 0.5500 - val_loss: 4.9042 - val_acc: 0.3705
# Epoch 30/150
#  - 2s - loss: 2.5200 - acc: 0.5667 - val_loss: 4.9300 - val_acc: 0.3649
# Epoch 31/150
#  - 2s - loss: 2.4827 - acc: 0.5567 - val_loss: 4.8790 - val_acc: 0.3677
# Epoch 32/150
#  - 2s - loss: 2.4199 - acc: 0.5633 - val_loss: 4.8697 - val_acc: 0.3733
# Epoch 33/150
#  - 2s - loss: 2.3633 - acc: 0.5667 - val_loss: 4.8689 - val_acc: 0.3677
# Epoch 34/150
#  - 2s - loss: 2.3307 - acc: 0.5733 - val_loss: 4.8134 - val_acc: 0.3621
# Epoch 35/150
#  - 2s - loss: 2.2594 - acc: 0.5867 - val_loss: 4.8010 - val_acc: 0.3760
# Epoch 36/150
#  - 2s - loss: 2.2151 - acc: 0.5967 - val_loss: 4.7831 - val_acc: 0.3760
# Epoch 37/150
#  - 2s - loss: 2.1650 - acc: 0.5833 - val_loss: 4.7498 - val_acc: 0.3677
# Epoch 38/150
#  - 2s - loss: 2.1313 - acc: 0.5900 - val_loss: 4.7503 - val_acc: 0.3733
# Epoch 39/150
#  - 2s - loss: 2.0812 - acc: 0.6033 - val_loss: 4.7515 - val_acc: 0.3816
# Epoch 40/150
#  - 2s - loss: 2.0530 - acc: 0.6167 - val_loss: 4.7285 - val_acc: 0.3844
# Epoch 41/150
#  - 2s - loss: 2.0081 - acc: 0.6200 - val_loss: 4.6962 - val_acc: 0.3705
# Epoch 42/150
#  - 2s - loss: 1.9754 - acc: 0.6200 - val_loss: 4.6804 - val_acc: 0.3677
# Epoch 43/150
#  - 2s - loss: 1.9391 - acc: 0.6267 - val_loss: 4.6731 - val_acc: 0.3705
# Epoch 44/150
#  - 2s - loss: 1.9052 - acc: 0.6400 - val_loss: 4.6682 - val_acc: 0.3677
# Epoch 45/150
#  - 2s - loss: 1.8810 - acc: 0.6533 - val_loss: 4.6647 - val_acc: 0.3705
# Epoch 46/150
#  - 2s - loss: 1.8426 - acc: 0.6633 - val_loss: 4.6518 - val_acc: 0.3733
# Epoch 47/150
#  - 2s - loss: 1.8211 - acc: 0.6500 - val_loss: 4.6361 - val_acc: 0.3677
# Epoch 48/150
#  - 2s - loss: 1.7895 - acc: 0.6633 - val_loss: 4.6745 - val_acc: 0.3705
# Epoch 49/150
#  - 2s - loss: 1.7573 - acc: 0.6633 - val_loss: 4.6455 - val_acc: 0.3705
# Epoch 50/150
#  - 2s - loss: 1.7325 - acc: 0.6733 - val_loss: 4.6249 - val_acc: 0.3788
# Epoch 51/150
#  - 2s - loss: 1.7082 - acc: 0.6767 - val_loss: 4.6089 - val_acc: 0.3760
# Epoch 52/150
#  - 2s - loss: 1.6822 - acc: 0.6933 - val_loss: 4.6117 - val_acc: 0.3760
# Epoch 53/150
#  - 2s - loss: 1.6578 - acc: 0.6800 - val_loss: 4.6300 - val_acc: 0.3816
# Epoch 54/150
#  - 2s - loss: 1.6232 - acc: 0.6833 - val_loss: 4.5761 - val_acc: 0.3760
# Epoch 55/150
#  - 2s - loss: 1.6042 - acc: 0.6933 - val_loss: 4.5791 - val_acc: 0.3844
# Epoch 56/150
#  - 2s - loss: 1.5813 - acc: 0.6867 - val_loss: 4.5858 - val_acc: 0.3872
# Epoch 57/150
#  - 2s - loss: 1.5533 - acc: 0.7033 - val_loss: 4.5607 - val_acc: 0.3816
# Epoch 58/150
#  - 2s - loss: 1.5330 - acc: 0.7100 - val_loss: 4.5598 - val_acc: 0.3872
# Epoch 59/150
#  - 2s - loss: 1.5078 - acc: 0.7133 - val_loss: 4.5624 - val_acc: 0.3928
# Epoch 60/150
#  - 2s - loss: 1.4845 - acc: 0.7067 - val_loss: 4.5498 - val_acc: 0.3928
# Epoch 61/150
#  - 2s - loss: 1.4628 - acc: 0.7233 - val_loss: 4.5293 - val_acc: 0.3844
# Epoch 62/150
#  - 2s - loss: 1.4451 - acc: 0.7267 - val_loss: 4.5195 - val_acc: 0.3955
# Epoch 63/150
#  - 2s - loss: 1.4280 - acc: 0.7233 - val_loss: 4.5666 - val_acc: 0.3928
# Epoch 64/150
#  - 2s - loss: 1.4026 - acc: 0.7367 - val_loss: 4.5237 - val_acc: 0.3928
# Epoch 65/150
#  - 2s - loss: 1.3819 - acc: 0.7300 - val_loss: 4.5295 - val_acc: 0.3928
# Epoch 66/150
#  - 2s - loss: 1.3629 - acc: 0.7333 - val_loss: 4.5098 - val_acc: 0.3928
# Epoch 67/150
#  - 2s - loss: 1.3400 - acc: 0.7600 - val_loss: 4.5289 - val_acc: 0.3928
# Epoch 68/150
#  - 2s - loss: 1.3246 - acc: 0.7633 - val_loss: 4.5105 - val_acc: 0.3928
# Epoch 69/150
#  - 2s - loss: 1.3060 - acc: 0.7567 - val_loss: 4.5017 - val_acc: 0.3928
# Epoch 70/150
#  - 2s - loss: 1.2889 - acc: 0.7667 - val_loss: 4.5244 - val_acc: 0.3928
# Epoch 71/150
#  - 2s - loss: 1.2711 - acc: 0.7700 - val_loss: 4.5038 - val_acc: 0.3955
# Epoch 72/150
#  - 2s - loss: 1.2543 - acc: 0.7667 - val_loss: 4.4935 - val_acc: 0.3928
# Epoch 73/150
#  - 2s - loss: 1.2399 - acc: 0.7733 - val_loss: 4.5024 - val_acc: 0.3928
# Epoch 74/150
#  - 2s - loss: 1.2263 - acc: 0.7733 - val_loss: 4.5071 - val_acc: 0.3900
# Epoch 75/150
#  - 2s - loss: 1.2109 - acc: 0.7867 - val_loss: 4.4763 - val_acc: 0.3928
# Epoch 76/150
#  - 2s - loss: 1.1987 - acc: 0.7833 - val_loss: 4.4891 - val_acc: 0.3928
# Epoch 77/150
#  - 2s - loss: 1.1817 - acc: 0.7867 - val_loss: 4.4815 - val_acc: 0.3928
# Epoch 78/150
#  - 2s - loss: 1.1702 - acc: 0.7900 - val_loss: 4.4781 - val_acc: 0.3955
# Epoch 79/150
#  - 2s - loss: 1.1552 - acc: 0.7900 - val_loss: 4.4742 - val_acc: 0.3900
# Epoch 80/150
#  - 2s - loss: 1.1413 - acc: 0.7933 - val_loss: 4.4729 - val_acc: 0.3955
# Epoch 81/150
#  - 2s - loss: 1.1345 - acc: 0.7833 - val_loss: 4.4853 - val_acc: 0.3928
# Epoch 82/150
#  - 2s - loss: 1.1182 - acc: 0.8033 - val_loss: 4.4608 - val_acc: 0.3983
# Epoch 83/150
#  - 2s - loss: 1.1107 - acc: 0.8067 - val_loss: 4.4669 - val_acc: 0.3983
# Epoch 84/150
#  - 2s - loss: 1.0932 - acc: 0.8000 - val_loss: 4.4890 - val_acc: 0.3816
# Epoch 85/150
#  - 2s - loss: 1.0818 - acc: 0.8067 - val_loss: 4.4694 - val_acc: 0.3900
# Epoch 86/150
#  - 2s - loss: 1.0730 - acc: 0.8067 - val_loss: 4.4671 - val_acc: 0.3955
# Epoch 87/150
#  - 2s - loss: 1.0586 - acc: 0.8100 - val_loss: 4.4828 - val_acc: 0.3788
# Epoch 88/150
#  - 2s - loss: 1.0505 - acc: 0.8133 - val_loss: 4.4781 - val_acc: 0.3816
# Epoch 89/150
#  - 2s - loss: 1.0395 - acc: 0.8200 - val_loss: 4.4669 - val_acc: 0.3844
# Epoch 90/150
#  - 2s - loss: 1.0306 - acc: 0.8267 - val_loss: 4.4734 - val_acc: 0.3844
# Epoch 91/150
#  - 2s - loss: 1.0223 - acc: 0.8200 - val_loss: 4.4695 - val_acc: 0.3844
# Epoch 92/150
#  - 2s - loss: 1.0111 - acc: 0.8300 - val_loss: 4.4586 - val_acc: 0.3872
# Epoch 93/150
#  - 2s - loss: 1.0021 - acc: 0.8333 - val_loss: 4.4658 - val_acc: 0.3844
# Epoch 94/150
#  - 2s - loss: 0.9919 - acc: 0.8300 - val_loss: 4.4721 - val_acc: 0.3816
# Epoch 95/150
#  - 2s - loss: 0.9853 - acc: 0.8267 - val_loss: 4.4772 - val_acc: 0.3816
# Epoch 96/150
#  - 2s - loss: 0.9738 - acc: 0.8267 - val_loss: 4.4567 - val_acc: 0.3872
# Epoch 97/150
#  - 2s - loss: 0.9644 - acc: 0.8333 - val_loss: 4.4639 - val_acc: 0.3872
# Epoch 98/150
#  - 2s - loss: 0.9576 - acc: 0.8367 - val_loss: 4.4653 - val_acc: 0.3872
# Epoch 99/150
#  - 2s - loss: 0.9478 - acc: 0.8367 - val_loss: 4.4635 - val_acc: 0.3872
# Epoch 100/150
#  - 2s - loss: 0.9412 - acc: 0.8367 - val_loss: 4.4621 - val_acc: 0.3872
# Epoch 101/150
#  - 2s - loss: 0.9335 - acc: 0.8400 - val_loss: 4.4638 - val_acc: 0.3844
# Epoch 102/150
#  - 2s - loss: 0.9260 - acc: 0.8500 - val_loss: 4.4634 - val_acc: 0.3788
# Epoch 103/150
#  - 2s - loss: 0.9201 - acc: 0.8500 - val_loss: 4.4550 - val_acc: 0.3816
# Epoch 104/150
#  - 2s - loss: 0.9103 - acc: 0.8500 - val_loss: 4.4584 - val_acc: 0.3844
# Epoch 105/150
#  - 2s - loss: 0.9036 - acc: 0.8500 - val_loss: 4.4689 - val_acc: 0.3816
# Epoch 106/150
#  - 2s - loss: 0.8987 - acc: 0.8567 - val_loss: 4.4624 - val_acc: 0.3816
# Epoch 107/150
#  - 2s - loss: 0.8907 - acc: 0.8567 - val_loss: 4.4495 - val_acc: 0.3844
# Epoch 108/150
#  - 2s - loss: 0.8843 - acc: 0.8567 - val_loss: 4.4477 - val_acc: 0.3816
# Epoch 109/150
#  - 2s - loss: 0.8763 - acc: 0.8633 - val_loss: 4.4535 - val_acc: 0.3816
# Epoch 110/150
#  - 2s - loss: 0.8713 - acc: 0.8600 - val_loss: 4.4496 - val_acc: 0.3816
# Epoch 111/150
#  - 2s - loss: 0.8667 - acc: 0.8633 - val_loss: 4.4523 - val_acc: 0.3816
# Epoch 112/150
#  - 2s - loss: 0.8577 - acc: 0.8633 - val_loss: 4.4545 - val_acc: 0.3816
# Epoch 113/150
#  - 2s - loss: 0.8520 - acc: 0.8700 - val_loss: 4.4503 - val_acc: 0.3816
# Epoch 114/150
#  - 2s - loss: 0.8463 - acc: 0.8633 - val_loss: 4.4461 - val_acc: 0.3816
# Epoch 115/150
#  - 2s - loss: 0.8399 - acc: 0.8667 - val_loss: 4.4461 - val_acc: 0.3844
# Epoch 116/150
#  - 2s - loss: 0.8329 - acc: 0.8733 - val_loss: 4.4398 - val_acc: 0.3844
# Epoch 117/150
#  - 2s - loss: 0.8283 - acc: 0.8733 - val_loss: 4.4392 - val_acc: 0.3816
# Epoch 118/150
#  - 2s - loss: 0.8224 - acc: 0.8733 - val_loss: 4.4354 - val_acc: 0.3844
# Epoch 119/150
#  - 2s - loss: 0.8171 - acc: 0.8767 - val_loss: 4.4369 - val_acc: 0.3844
# Epoch 120/150
#  - 2s - loss: 0.8118 - acc: 0.8800 - val_loss: 4.4319 - val_acc: 0.3844
# Epoch 121/150
#  - 2s - loss: 0.8073 - acc: 0.8800 - val_loss: 4.4436 - val_acc: 0.3816
# Epoch 122/150
#  - 2s - loss: 0.8029 - acc: 0.8800 - val_loss: 4.4451 - val_acc: 0.3872
# Epoch 123/150
#  - 2s - loss: 0.7962 - acc: 0.8867 - val_loss: 4.4275 - val_acc: 0.3844
# Epoch 124/150
#  - 2s - loss: 0.7926 - acc: 0.8867 - val_loss: 4.4240 - val_acc: 0.3844
# Epoch 125/150
#  - 2s - loss: 0.7855 - acc: 0.8800 - val_loss: 4.4379 - val_acc: 0.3872
# Epoch 126/150
#  - 2s - loss: 0.7810 - acc: 0.8867 - val_loss: 4.4391 - val_acc: 0.3872
# Epoch 127/150
#  - 2s - loss: 0.7751 - acc: 0.8867 - val_loss: 4.4493 - val_acc: 0.3872
# Epoch 128/150
#  - 2s - loss: 0.7702 - acc: 0.8867 - val_loss: 4.4359 - val_acc: 0.3872
# Epoch 129/150
#  - 2s - loss: 0.7655 - acc: 0.8867 - val_loss: 4.4318 - val_acc: 0.3816
# Epoch 130/150
#  - 2s - loss: 0.7603 - acc: 0.8867 - val_loss: 4.4456 - val_acc: 0.3844
# Epoch 131/150
#  - 2s - loss: 0.7566 - acc: 0.8867 - val_loss: 4.4317 - val_acc: 0.3816
# Epoch 132/150
#  - 2s - loss: 0.7526 - acc: 0.8900 - val_loss: 4.4406 - val_acc: 0.3816
# Epoch 133/150
#  - 2s - loss: 0.7470 - acc: 0.8900 - val_loss: 4.4212 - val_acc: 0.3872
# Epoch 134/150
#  - 2s - loss: 0.7413 - acc: 0.8900 - val_loss: 4.4260 - val_acc: 0.3844
# Epoch 135/150
#  - 2s - loss: 0.7380 - acc: 0.8933 - val_loss: 4.4156 - val_acc: 0.3872
# Epoch 136/150
#  - 2s - loss: 0.7325 - acc: 0.8933 - val_loss: 4.4075 - val_acc: 0.3844
# Epoch 137/150
#  - 2s - loss: 0.7276 - acc: 0.8967 - val_loss: 4.4107 - val_acc: 0.3844
# Epoch 138/150
#  - 2s - loss: 0.7223 - acc: 0.9000 - val_loss: 4.4006 - val_acc: 0.3844
# Epoch 139/150
#  - 2s - loss: 0.7179 - acc: 0.9000 - val_loss: 4.3865 - val_acc: 0.3900
# Epoch 140/150
#  - 2s - loss: 0.7126 - acc: 0.8967 - val_loss: 4.3893 - val_acc: 0.3788
# Epoch 141/150
#  - 2s - loss: 0.7077 - acc: 0.8967 - val_loss: 4.3900 - val_acc: 0.3788
# Epoch 142/150
#  - 2s - loss: 0.7054 - acc: 0.8933 - val_loss: 4.4075 - val_acc: 0.3816
# Epoch 143/150
#  - 2s - loss: 0.6983 - acc: 0.9000 - val_loss: 4.3802 - val_acc: 0.3816
# Epoch 144/150
#  - 2s - loss: 0.6943 - acc: 0.9000 - val_loss: 4.3708 - val_acc: 0.3844
# Epoch 145/150
#  - 2s - loss: 0.6903 - acc: 0.9000 - val_loss: 4.3912 - val_acc: 0.3816
# Epoch 146/150
#  - 2s - loss: 0.6845 - acc: 0.9000 - val_loss: 4.3861 - val_acc: 0.3872
# Epoch 147/150
#  - 2s - loss: 0.6801 - acc: 0.9000 - val_loss: 4.3854 - val_acc: 0.3872
# Epoch 148/150
#  - 2s - loss: 0.6766 - acc: 0.9000 - val_loss: 4.3812 - val_acc: 0.3900
# Epoch 149/150
#  - 2s - loss: 0.6726 - acc: 0.9000 - val_loss: 4.3870 - val_acc: 0.3900
# Epoch 150/150
#  - 2s - loss: 0.6689 - acc: 0.9000 - val_loss: 4.3831 - val_acc: 0.3900
# Timing:  278.46668672561646
# model_info_3 history Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/hist_my_VGG16_03_64filt_gu0_50nod_1.pkl
# add line
# df_res_filters_gu0_50nod Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/df_res_filters_gu0_50nod.pkl
# nb_try:  2
# Model: "my_VGG16_03_64filt_gu0_50nod_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 200704)            0
# _________________________________________________________________
# dense_15 (Dense)             (None, 50)                10035250
# _________________________________________________________________
# dense_16 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 10,074,123
# Trainable params: 10,074,123
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Train on 300 samples, validate on 359 samples
# Epoch 1/150
#  - 2s - loss: 7.5578 - acc: 0.3600 - val_loss: 8.2482 - val_acc: 0.3036
# Epoch 2/150
#  - 2s - loss: 7.0857 - acc: 0.3533 - val_loss: 7.6459 - val_acc: 0.2981
# Epoch 3/150
#  - 2s - loss: 6.5145 - acc: 0.3567 - val_loss: 7.1910 - val_acc: 0.3036
# Epoch 4/150
#  - 2s - loss: 6.0728 - acc: 0.3867 - val_loss: 6.9199 - val_acc: 0.3287
# Epoch 5/150
#  - 2s - loss: 5.7775 - acc: 0.4033 - val_loss: 6.7549 - val_acc: 0.3315
# Epoch 6/150
#  - 2s - loss: 5.5150 - acc: 0.4033 - val_loss: 6.7082 - val_acc: 0.3398
# Epoch 7/150
#  - 2s - loss: 5.2662 - acc: 0.4167 - val_loss: 6.6273 - val_acc: 0.3370
# Epoch 8/150
#  - 2s - loss: 5.0674 - acc: 0.4300 - val_loss: 6.5696 - val_acc: 0.3370
# Epoch 9/150
#  - 2s - loss: 4.8561 - acc: 0.4300 - val_loss: 6.3140 - val_acc: 0.3343
# Epoch 10/150
#  - 2s - loss: 4.6490 - acc: 0.4300 - val_loss: 6.1443 - val_acc: 0.3398
# Epoch 11/150
#  - 2s - loss: 4.4438 - acc: 0.4367 - val_loss: 6.0246 - val_acc: 0.3510
# Epoch 12/150
#  - 2s - loss: 4.2718 - acc: 0.4367 - val_loss: 5.8901 - val_acc: 0.3593
# Epoch 13/150
#  - 2s - loss: 4.1015 - acc: 0.4467 - val_loss: 5.8194 - val_acc: 0.3565
# Epoch 14/150
#  - 2s - loss: 3.9548 - acc: 0.4500 - val_loss: 5.6931 - val_acc: 0.3593
# Epoch 15/150
#  - 2s - loss: 3.8368 - acc: 0.4667 - val_loss: 5.6441 - val_acc: 0.3565
# Epoch 16/150
#  - 2s - loss: 3.7267 - acc: 0.4767 - val_loss: 5.5983 - val_acc: 0.3593
# Epoch 17/150
#  - 2s - loss: 3.5961 - acc: 0.4800 - val_loss: 5.4832 - val_acc: 0.3621
# Epoch 18/150
#  - 2s - loss: 3.5044 - acc: 0.4867 - val_loss: 5.4870 - val_acc: 0.3621
# Epoch 19/150
#  - 2s - loss: 3.4160 - acc: 0.4900 - val_loss: 5.5065 - val_acc: 0.3510
# Epoch 20/150
#  - 2s - loss: 3.3165 - acc: 0.5000 - val_loss: 5.3639 - val_acc: 0.3705
# Epoch 21/150
#  - 2s - loss: 3.2390 - acc: 0.5133 - val_loss: 5.3116 - val_acc: 0.3621
# Epoch 22/150
#  - 2s - loss: 3.1329 - acc: 0.5133 - val_loss: 5.2888 - val_acc: 0.3649
# Epoch 23/150
#  - 2s - loss: 3.0493 - acc: 0.5133 - val_loss: 5.2481 - val_acc: 0.3593
# Epoch 24/150
#  - 2s - loss: 2.9891 - acc: 0.5133 - val_loss: 5.2100 - val_acc: 0.3593
# Epoch 25/150
#  - 2s - loss: 2.8972 - acc: 0.5233 - val_loss: 5.1481 - val_acc: 0.3677
# Epoch 26/150
#  - 2s - loss: 2.8264 - acc: 0.5300 - val_loss: 5.1395 - val_acc: 0.3677
# Epoch 27/150
#  - 2s - loss: 2.7624 - acc: 0.5367 - val_loss: 5.1145 - val_acc: 0.3677
# Epoch 28/150
#  - 2s - loss: 2.7032 - acc: 0.5433 - val_loss: 5.1393 - val_acc: 0.3510
# Epoch 29/150
#  - 2s - loss: 2.6173 - acc: 0.5433 - val_loss: 5.0362 - val_acc: 0.3788
# Epoch 30/150
#  - 2s - loss: 2.5800 - acc: 0.5400 - val_loss: 5.0192 - val_acc: 0.3705
# Epoch 31/150
#  - 2s - loss: 2.4939 - acc: 0.5500 - val_loss: 5.0687 - val_acc: 0.3565
# Epoch 32/150
#  - 2s - loss: 2.4516 - acc: 0.5567 - val_loss: 5.0095 - val_acc: 0.3621
# Epoch 33/150
#  - 2s - loss: 2.3901 - acc: 0.5667 - val_loss: 4.9936 - val_acc: 0.3677
# Epoch 34/150
#  - 2s - loss: 2.3378 - acc: 0.5633 - val_loss: 4.9632 - val_acc: 0.3705
# Epoch 35/150
#  - 2s - loss: 2.2907 - acc: 0.5667 - val_loss: 4.9573 - val_acc: 0.3705
# Epoch 36/150
#  - 2s - loss: 2.2502 - acc: 0.5767 - val_loss: 4.9544 - val_acc: 0.3733
# Epoch 37/150
#  - 2s - loss: 2.2120 - acc: 0.5800 - val_loss: 4.9378 - val_acc: 0.3733
# Epoch 38/150
#  - 2s - loss: 2.1706 - acc: 0.5833 - val_loss: 4.9241 - val_acc: 0.3733
# Epoch 39/150
#  - 2s - loss: 2.1285 - acc: 0.5933 - val_loss: 4.9122 - val_acc: 0.3705
# Epoch 40/150
#  - 2s - loss: 2.0807 - acc: 0.5967 - val_loss: 4.9316 - val_acc: 0.3649
# Epoch 41/150
#  - 2s - loss: 2.0555 - acc: 0.6100 - val_loss: 4.8999 - val_acc: 0.3677
# Epoch 42/150
#  - 2s - loss: 2.0185 - acc: 0.6167 - val_loss: 4.8846 - val_acc: 0.3705
# Epoch 43/150
#  - 2s - loss: 1.9884 - acc: 0.6267 - val_loss: 4.8655 - val_acc: 0.3705
# Epoch 44/150
#  - 2s - loss: 1.9555 - acc: 0.6267 - val_loss: 4.8606 - val_acc: 0.3760
# Epoch 45/150
#  - 2s - loss: 1.9261 - acc: 0.6300 - val_loss: 4.8628 - val_acc: 0.3705
# Epoch 46/150
#  - 2s - loss: 1.8903 - acc: 0.6333 - val_loss: 4.8415 - val_acc: 0.3760
# Epoch 47/150
#  - 2s - loss: 1.8574 - acc: 0.6433 - val_loss: 4.8022 - val_acc: 0.3788
# Epoch 48/150
#  - 2s - loss: 1.8328 - acc: 0.6667 - val_loss: 4.7852 - val_acc: 0.3816
# Epoch 49/150
#  - 2s - loss: 1.7983 - acc: 0.6633 - val_loss: 4.8054 - val_acc: 0.3788
# Epoch 50/150
#  - 2s - loss: 1.7720 - acc: 0.6600 - val_loss: 4.7901 - val_acc: 0.3788
# Epoch 51/150
#  - 2s - loss: 1.7451 - acc: 0.6700 - val_loss: 4.7484 - val_acc: 0.3816
# Epoch 52/150
#  - 2s - loss: 1.7227 - acc: 0.6867 - val_loss: 4.7673 - val_acc: 0.3788
# Epoch 53/150
#  - 2s - loss: 1.6955 - acc: 0.6833 - val_loss: 4.7672 - val_acc: 0.3788
# Epoch 54/150
#  - 2s - loss: 1.6704 - acc: 0.6833 - val_loss: 4.7791 - val_acc: 0.3788
# Epoch 55/150
#  - 2s - loss: 1.6485 - acc: 0.6867 - val_loss: 4.7758 - val_acc: 0.3816
# Epoch 56/150
#  - 2s - loss: 1.6231 - acc: 0.6967 - val_loss: 4.7664 - val_acc: 0.3816
# Epoch 57/150
#  - 2s - loss: 1.6050 - acc: 0.6933 - val_loss: 4.7696 - val_acc: 0.3788
# Epoch 58/150
#  - 2s - loss: 1.5800 - acc: 0.6967 - val_loss: 4.7552 - val_acc: 0.3788
# Epoch 59/150
#  - 2s - loss: 1.5589 - acc: 0.7100 - val_loss: 4.7551 - val_acc: 0.3816
# Epoch 60/150
#  - 2s - loss: 1.5343 - acc: 0.7233 - val_loss: 4.7434 - val_acc: 0.3788
# Epoch 61/150
#  - 2s - loss: 1.5124 - acc: 0.7233 - val_loss: 4.7653 - val_acc: 0.3816
# Epoch 62/150
#  - 2s - loss: 1.5003 - acc: 0.7133 - val_loss: 4.7541 - val_acc: 0.3816
# Epoch 63/150
#  - 2s - loss: 1.4790 - acc: 0.7200 - val_loss: 4.7495 - val_acc: 0.3788
# Epoch 64/150
#  - 2s - loss: 1.4620 - acc: 0.7300 - val_loss: 4.7336 - val_acc: 0.3788
# Epoch 65/150
#  - 2s - loss: 1.4397 - acc: 0.7400 - val_loss: 4.7582 - val_acc: 0.3788
# Epoch 66/150
#  - 2s - loss: 1.4257 - acc: 0.7367 - val_loss: 4.7596 - val_acc: 0.3788
# Epoch 67/150
#  - 2s - loss: 1.4071 - acc: 0.7467 - val_loss: 4.7397 - val_acc: 0.3788
# Epoch 68/150
#  - 2s - loss: 1.3942 - acc: 0.7533 - val_loss: 4.7354 - val_acc: 0.3788
# Epoch 69/150
#  - 2s - loss: 1.3766 - acc: 0.7600 - val_loss: 4.7378 - val_acc: 0.3816
# Epoch 70/150
#  - 2s - loss: 1.3650 - acc: 0.7667 - val_loss: 4.7446 - val_acc: 0.3760
# Epoch 71/150
#  - 2s - loss: 1.3526 - acc: 0.7800 - val_loss: 4.7210 - val_acc: 0.3788
# Epoch 72/150
#  - 2s - loss: 1.3329 - acc: 0.7767 - val_loss: 4.7234 - val_acc: 0.3788
# Epoch 73/150
#  - 2s - loss: 1.3221 - acc: 0.7767 - val_loss: 4.7269 - val_acc: 0.3760
# Epoch 74/150
#  - 2s - loss: 1.3077 - acc: 0.7867 - val_loss: 4.7420 - val_acc: 0.3788
# Epoch 75/150
#  - 2s - loss: 1.2945 - acc: 0.7900 - val_loss: 4.7068 - val_acc: 0.3844
# Epoch 76/150
#  - 2s - loss: 1.2841 - acc: 0.7967 - val_loss: 4.7069 - val_acc: 0.3816
# Epoch 77/150
#  - 2s - loss: 1.2689 - acc: 0.7867 - val_loss: 4.7037 - val_acc: 0.3872
# Epoch 78/150
#  - 2s - loss: 1.2594 - acc: 0.8100 - val_loss: 4.7132 - val_acc: 0.3788
# Epoch 79/150
#  - 2s - loss: 1.2418 - acc: 0.8067 - val_loss: 4.7196 - val_acc: 0.3788
# Epoch 80/150
#  - 2s - loss: 1.2324 - acc: 0.8067 - val_loss: 4.7011 - val_acc: 0.3844
# Epoch 81/150
#  - 2s - loss: 1.2176 - acc: 0.8067 - val_loss: 4.7110 - val_acc: 0.3816
# Epoch 82/150
#  - 2s - loss: 1.2094 - acc: 0.8100 - val_loss: 4.7081 - val_acc: 0.3760
# Epoch 83/150
#  - 2s - loss: 1.1969 - acc: 0.8033 - val_loss: 4.7043 - val_acc: 0.3844
# Epoch 84/150
#  - 2s - loss: 1.1845 - acc: 0.8167 - val_loss: 4.7222 - val_acc: 0.3816
# Epoch 85/150
#  - 2s - loss: 1.1744 - acc: 0.8167 - val_loss: 4.6974 - val_acc: 0.3788
# Epoch 86/150
#  - 2s - loss: 1.1633 - acc: 0.8167 - val_loss: 4.6964 - val_acc: 0.3788
# Epoch 87/150
#  - 2s - loss: 1.1530 - acc: 0.8200 - val_loss: 4.6968 - val_acc: 0.3816
# Epoch 88/150
#  - 2s - loss: 1.1449 - acc: 0.8167 - val_loss: 4.6883 - val_acc: 0.3816
# Epoch 89/150
#  - 2s - loss: 1.1351 - acc: 0.8267 - val_loss: 4.6884 - val_acc: 0.3844
# Epoch 90/150
#  - 2s - loss: 1.1244 - acc: 0.8267 - val_loss: 4.6755 - val_acc: 0.3788
# Epoch 91/150
#  - 2s - loss: 1.1161 - acc: 0.8333 - val_loss: 4.6742 - val_acc: 0.3788
# Epoch 92/150
#  - 2s - loss: 1.1066 - acc: 0.8300 - val_loss: 4.6789 - val_acc: 0.3844
# Epoch 93/150
#  - 2s - loss: 1.0980 - acc: 0.8367 - val_loss: 4.6775 - val_acc: 0.3816
# Epoch 94/150
#  - 2s - loss: 1.0888 - acc: 0.8367 - val_loss: 4.6700 - val_acc: 0.3816
# Epoch 95/150
#  - 2s - loss: 1.0813 - acc: 0.8367 - val_loss: 4.6844 - val_acc: 0.3816
# Epoch 96/150
#  - 2s - loss: 1.0765 - acc: 0.8367 - val_loss: 4.6703 - val_acc: 0.3844
# Epoch 97/150
#  - 2s - loss: 1.0626 - acc: 0.8367 - val_loss: 4.6904 - val_acc: 0.3816
# Epoch 98/150
#  - 2s - loss: 1.0547 - acc: 0.8400 - val_loss: 4.6849 - val_acc: 0.3788
# Epoch 99/150
#  - 2s - loss: 1.0460 - acc: 0.8467 - val_loss: 4.6679 - val_acc: 0.3872
# Epoch 100/150
#  - 2s - loss: 1.0392 - acc: 0.8467 - val_loss: 4.6769 - val_acc: 0.3816
# Epoch 101/150
#  - 2s - loss: 1.0314 - acc: 0.8500 - val_loss: 4.6741 - val_acc: 0.3816
# Epoch 102/150
#  - 2s - loss: 1.0236 - acc: 0.8567 - val_loss: 4.6677 - val_acc: 0.3844
# Epoch 103/150
#  - 2s - loss: 1.0192 - acc: 0.8500 - val_loss: 4.6691 - val_acc: 0.3816
# Epoch 104/150
#  - 2s - loss: 1.0099 - acc: 0.8633 - val_loss: 4.6748 - val_acc: 0.3760
# Epoch 105/150
#  - 2s - loss: 1.0043 - acc: 0.8667 - val_loss: 4.6850 - val_acc: 0.3760
# Epoch 106/150
#  - 2s - loss: 0.9955 - acc: 0.8700 - val_loss: 4.6557 - val_acc: 0.3816
# Epoch 107/150
#  - 2s - loss: 0.9888 - acc: 0.8667 - val_loss: 4.6506 - val_acc: 0.3788
# Epoch 108/150
#  - 2s - loss: 0.9841 - acc: 0.8600 - val_loss: 4.6513 - val_acc: 0.3788
# Epoch 109/150
#  - 2s - loss: 0.9792 - acc: 0.8633 - val_loss: 4.6517 - val_acc: 0.3788
# Epoch 110/150
#  - 2s - loss: 0.9699 - acc: 0.8700 - val_loss: 4.6742 - val_acc: 0.3733
# Epoch 111/150
#  - 2s - loss: 0.9630 - acc: 0.8700 - val_loss: 4.6685 - val_acc: 0.3760
# Epoch 112/150
#  - 2s - loss: 0.9563 - acc: 0.8733 - val_loss: 4.6676 - val_acc: 0.3733
# Epoch 113/150
#  - 2s - loss: 0.9506 - acc: 0.8767 - val_loss: 4.6602 - val_acc: 0.3788
# Epoch 114/150
#  - 2s - loss: 0.9440 - acc: 0.8733 - val_loss: 4.6709 - val_acc: 0.3733
# Epoch 115/150
#  - 2s - loss: 0.9391 - acc: 0.8700 - val_loss: 4.6656 - val_acc: 0.3733
# Epoch 116/150
#  - 2s - loss: 0.9352 - acc: 0.8733 - val_loss: 4.6570 - val_acc: 0.3788
# Epoch 117/150
#  - 2s - loss: 0.9292 - acc: 0.8800 - val_loss: 4.6652 - val_acc: 0.3816
# Epoch 118/150
#  - 2s - loss: 0.9233 - acc: 0.8800 - val_loss: 4.6576 - val_acc: 0.3788
# Epoch 119/150
#  - 2s - loss: 0.9181 - acc: 0.8867 - val_loss: 4.6547 - val_acc: 0.3788
# Epoch 120/150
#  - 2s - loss: 0.9135 - acc: 0.8900 - val_loss: 4.6547 - val_acc: 0.3844
# Epoch 121/150
#  - 2s - loss: 0.9084 - acc: 0.8900 - val_loss: 4.6615 - val_acc: 0.3844
# Epoch 122/150
#  - 2s - loss: 0.9042 - acc: 0.8867 - val_loss: 4.6551 - val_acc: 0.3844
# Epoch 123/150
#  - 2s - loss: 0.8996 - acc: 0.8900 - val_loss: 4.6579 - val_acc: 0.3733
# Epoch 124/150
#  - 2s - loss: 0.8970 - acc: 0.8900 - val_loss: 4.6591 - val_acc: 0.3705
# Epoch 125/150
#  - 2s - loss: 0.8902 - acc: 0.8933 - val_loss: 4.6448 - val_acc: 0.3788
# Epoch 126/150
#  - 2s - loss: 0.8862 - acc: 0.8933 - val_loss: 4.6484 - val_acc: 0.3788
# Epoch 127/150
#  - 2s - loss: 0.8826 - acc: 0.8933 - val_loss: 4.6567 - val_acc: 0.3760
# Epoch 128/150
#  - 2s - loss: 0.8774 - acc: 0.8933 - val_loss: 4.6508 - val_acc: 0.3760
# Epoch 129/150
#  - 2s - loss: 0.8743 - acc: 0.8933 - val_loss: 4.6561 - val_acc: 0.3760
# Epoch 130/150
#  - 2s - loss: 0.8714 - acc: 0.8933 - val_loss: 4.6590 - val_acc: 0.3760
# Epoch 131/150
#  - 2s - loss: 0.8663 - acc: 0.8933 - val_loss: 4.6511 - val_acc: 0.3733
# Epoch 132/150
#  - 2s - loss: 0.8629 - acc: 0.8933 - val_loss: 4.6391 - val_acc: 0.3733
# Epoch 133/150
#  - 2s - loss: 0.8589 - acc: 0.8933 - val_loss: 4.6413 - val_acc: 0.3760
# Epoch 134/150
#  - 2s - loss: 0.8557 - acc: 0.8933 - val_loss: 4.6423 - val_acc: 0.3760
# Epoch 135/150
#  - 2s - loss: 0.8516 - acc: 0.8933 - val_loss: 4.6381 - val_acc: 0.3788
# Epoch 136/150
#  - 2s - loss: 0.8479 - acc: 0.8967 - val_loss: 4.6502 - val_acc: 0.3760
# Epoch 137/150
#  - 2s - loss: 0.8452 - acc: 0.9000 - val_loss: 4.6481 - val_acc: 0.3760
# Epoch 138/150
#  - 2s - loss: 0.8419 - acc: 0.9000 - val_loss: 4.6556 - val_acc: 0.3733
# Epoch 139/150
#  - 2s - loss: 0.8379 - acc: 0.9000 - val_loss: 4.6389 - val_acc: 0.3760
# Epoch 140/150
#  - 2s - loss: 0.8365 - acc: 0.8967 - val_loss: 4.6270 - val_acc: 0.3760
# Epoch 141/150
#  - 2s - loss: 0.8335 - acc: 0.9000 - val_loss: 4.6427 - val_acc: 0.3760
# Epoch 142/150
#  - 2s - loss: 0.8291 - acc: 0.9033 - val_loss: 4.6295 - val_acc: 0.3760
# Epoch 143/150
#  - 2s - loss: 0.8267 - acc: 0.9000 - val_loss: 4.6401 - val_acc: 0.3733
# Epoch 144/150
#  - 2s - loss: 0.8240 - acc: 0.9000 - val_loss: 4.6241 - val_acc: 0.3788
# Epoch 145/150
#  - 2s - loss: 0.8209 - acc: 0.9033 - val_loss: 4.6343 - val_acc: 0.3760
# Epoch 146/150
#  - 2s - loss: 0.8175 - acc: 0.9033 - val_loss: 4.6359 - val_acc: 0.3760
# Epoch 147/150
#  - 2s - loss: 0.8150 - acc: 0.9100 - val_loss: 4.6437 - val_acc: 0.3733
# Epoch 148/150
#  - 2s - loss: 0.8125 - acc: 0.9067 - val_loss: 4.6363 - val_acc: 0.3760
# Epoch 149/150
#  - 2s - loss: 0.8097 - acc: 0.9133 - val_loss: 4.6394 - val_acc: 0.3760
# Epoch 150/150
#  - 2s - loss: 0.8078 - acc: 0.9133 - val_loss: 4.6318 - val_acc: 0.3760
# Timing:  278.6850006580353
# model_info_3 history Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/hist_my_VGG16_03_64filt_gu0_50nod_2.pkl
# add line
# df_res_filters_gu0_50nod Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/df_res_filters_gu0_50nod.pkl
# nb_filters:  128
# nb_try:  0
# Model: "my_VGG16_03_128filt_gu0_50nod_0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 224, 224, 128)     3584
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 112, 112, 128)     0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 56, 56, 128)       0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 401408)            0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                20070450
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 20,221,771
# Trainable params: 20,221,771
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Train on 300 samples, validate on 359 samples
# Epoch 1/150
#  - 7s - loss: 6.7090 - acc: 0.3367 - val_loss: 6.6327 - val_acc: 0.3343
# Epoch 2/150
#  - 4s - loss: 5.9640 - acc: 0.3667 - val_loss: 6.1389 - val_acc: 0.3259
# Epoch 3/150
#  - 4s - loss: 5.3080 - acc: 0.3467 - val_loss: 5.9625 - val_acc: 0.3398
# Epoch 4/150
#  - 4s - loss: 4.9657 - acc: 0.3833 - val_loss: 5.8307 - val_acc: 0.3510
# Epoch 5/150
#  - 4s - loss: 4.7021 - acc: 0.3900 - val_loss: 5.7539 - val_acc: 0.3538
# Epoch 6/150
#  - 4s - loss: 4.4900 - acc: 0.4100 - val_loss: 5.6893 - val_acc: 0.3565
# Epoch 7/150
#  - 4s - loss: 4.2782 - acc: 0.4100 - val_loss: 5.6351 - val_acc: 0.3538
# Epoch 8/150
#  - 4s - loss: 4.0874 - acc: 0.4300 - val_loss: 5.5520 - val_acc: 0.3649
# Epoch 9/150
#  - 4s - loss: 3.9417 - acc: 0.4400 - val_loss: 5.4848 - val_acc: 0.3705
# Epoch 10/150
#  - 4s - loss: 3.7410 - acc: 0.4600 - val_loss: 5.4427 - val_acc: 0.3649
# Epoch 11/150
#  - 4s - loss: 3.5941 - acc: 0.4567 - val_loss: 5.3867 - val_acc: 0.3705
# Epoch 12/150
#  - 4s - loss: 3.4549 - acc: 0.4733 - val_loss: 5.3461 - val_acc: 0.3733
# Epoch 13/150
#  - 4s - loss: 3.3086 - acc: 0.4967 - val_loss: 5.3057 - val_acc: 0.3760
# Epoch 14/150
#  - 4s - loss: 3.1879 - acc: 0.4900 - val_loss: 5.2541 - val_acc: 0.3760
# Epoch 15/150
#  - 4s - loss: 3.0756 - acc: 0.4967 - val_loss: 5.2078 - val_acc: 0.3788
# Epoch 16/150
#  - 4s - loss: 2.9298 - acc: 0.5033 - val_loss: 5.1581 - val_acc: 0.3677
# Epoch 17/150
#  - 4s - loss: 2.8179 - acc: 0.5333 - val_loss: 5.1160 - val_acc: 0.3733
# Epoch 18/150
#  - 4s - loss: 2.6852 - acc: 0.5300 - val_loss: 5.0720 - val_acc: 0.3760
# Epoch 19/150
#  - 4s - loss: 2.5833 - acc: 0.5533 - val_loss: 5.0187 - val_acc: 0.3705
# Epoch 20/150
#  - 4s - loss: 2.4437 - acc: 0.5733 - val_loss: 4.9599 - val_acc: 0.3760
# Epoch 21/150
#  - 4s - loss: 2.3946 - acc: 0.5700 - val_loss: 4.9287 - val_acc: 0.3705
# Epoch 22/150
#  - 4s - loss: 2.2699 - acc: 0.5867 - val_loss: 4.8960 - val_acc: 0.3733
# Epoch 23/150
#  - 4s - loss: 2.1904 - acc: 0.5933 - val_loss: 4.8554 - val_acc: 0.3788
# Epoch 24/150
#  - 4s - loss: 2.0997 - acc: 0.6000 - val_loss: 4.8463 - val_acc: 0.3788
# Epoch 25/150
#  - 4s - loss: 2.0332 - acc: 0.6233 - val_loss: 4.7931 - val_acc: 0.3872
# Epoch 26/150
#  - 4s - loss: 1.9428 - acc: 0.6100 - val_loss: 4.7692 - val_acc: 0.3928
# Epoch 27/150
#  - 4s - loss: 1.8737 - acc: 0.6267 - val_loss: 4.7291 - val_acc: 0.3955
# Epoch 28/150
#  - 4s - loss: 1.8015 - acc: 0.6233 - val_loss: 4.7008 - val_acc: 0.3955
# Epoch 29/150
#  - 4s - loss: 1.7359 - acc: 0.6333 - val_loss: 4.6881 - val_acc: 0.3928
# Epoch 30/150
#  - 4s - loss: 1.6877 - acc: 0.6533 - val_loss: 4.6777 - val_acc: 0.3872
# Epoch 31/150
# ...
# Epoch 24/150
#  - 8s - loss: 0.9131 - acc: 0.7333 - val_loss: 3.4080 - val_acc: 0.4123
# Epoch 25/150
#  - 8s - loss: 0.8600 - acc: 0.7433 - val_loss: 3.4001 - val_acc: 0.4150
# Epoch 26/150
#  - 8s - loss: 0.8305 - acc: 0.7667 - val_loss: 3.4012 - val_acc: 0.4178
# Epoch 27/150
#  - 8s - loss: 0.7907 - acc: 0.7700 - val_loss: 3.3757 - val_acc: 0.4262
# Epoch 28/150
#  - 8s - loss: 0.7544 - acc: 0.7967 - val_loss: 3.3598 - val_acc: 0.4262
# Epoch 29/150
#  - 8s - loss: 0.7190 - acc: 0.8100 - val_loss: 3.3395 - val_acc: 0.4318
# Epoch 30/150
#  - 8s - loss: 0.6855 - acc: 0.8200 - val_loss: 3.3345 - val_acc: 0.4234
# Epoch 31/150
#  - 8s - loss: 0.6566 - acc: 0.8233 - val_loss: 3.3313 - val_acc: 0.4234
# Epoch 32/150
#  - 8s - loss: 0.6281 - acc: 0.8333 - val_loss: 3.3216 - val_acc: 0.4234
# Epoch 33/150
#  - 8s - loss: 0.6031 - acc: 0.8367 - val_loss: 3.3175 - val_acc: 0.4262
# Epoch 34/150
#  - 8s - loss: 0.5815 - acc: 0.8467 - val_loss: 3.3197 - val_acc: 0.4234
# Epoch 35/150
#  - 8s - loss: 0.5581 - acc: 0.8733 - val_loss: 3.3161 - val_acc: 0.4234
# Epoch 36/150
#  - 8s - loss: 0.5339 - acc: 0.8800 - val_loss: 3.3145 - val_acc: 0.4206
# Epoch 37/150
#  - 8s - loss: 0.5163 - acc: 0.8867 - val_loss: 3.3066 - val_acc: 0.4234
# Epoch 38/150
#  - 8s - loss: 0.5006 - acc: 0.8867 - val_loss: 3.3050 - val_acc: 0.4234
# Epoch 39/150
#  - 8s - loss: 0.4892 - acc: 0.8767 - val_loss: 3.2899 - val_acc: 0.4262
# Epoch 40/150
#  - 8s - loss: 0.4697 - acc: 0.8967 - val_loss: 3.2858 - val_acc: 0.4234
# Epoch 41/150
#  - 8s - loss: 0.4527 - acc: 0.9033 - val_loss: 3.2887 - val_acc: 0.4318
# Epoch 42/150
#  - 8s - loss: 0.4398 - acc: 0.9067 - val_loss: 3.2823 - val_acc: 0.4234
# Epoch 43/150
#  - 8s - loss: 0.4238 - acc: 0.9133 - val_loss: 3.2762 - val_acc: 0.4262
# Epoch 44/150
#  - 8s - loss: 0.4082 - acc: 0.9267 - val_loss: 3.2801 - val_acc: 0.4234
# Epoch 45/150
#  - 8s - loss: 0.3960 - acc: 0.9267 - val_loss: 3.2744 - val_acc: 0.4262
# Epoch 46/150
#  - 8s - loss: 0.3858 - acc: 0.9267 - val_loss: 3.2634 - val_acc: 0.4290
# Epoch 47/150
#  - 8s - loss: 0.3733 - acc: 0.9267 - val_loss: 3.2640 - val_acc: 0.4318
# Epoch 48/150
#  - 8s - loss: 0.3617 - acc: 0.9333 - val_loss: 3.2566 - val_acc: 0.4318
# Epoch 49/150
#  - 8s - loss: 0.3526 - acc: 0.9400 - val_loss: 3.2537 - val_acc: 0.4318
# Epoch 50/150
#  - 8s - loss: 0.3416 - acc: 0.9400 - val_loss: 3.2629 - val_acc: 0.4373
# Epoch 51/150
#  - 8s - loss: 0.3322 - acc: 0.9433 - val_loss: 3.2674 - val_acc: 0.4318
# Epoch 52/150
#  - 8s - loss: 0.3236 - acc: 0.9467 - val_loss: 3.2530 - val_acc: 0.4290
# Epoch 53/150
#  - 8s - loss: 0.3145 - acc: 0.9400 - val_loss: 3.2514 - val_acc: 0.4373
# Epoch 54/150
#  - 8s - loss: 0.3069 - acc: 0.9500 - val_loss: 3.2545 - val_acc: 0.4345
# Epoch 55/150
#  - 8s - loss: 0.2995 - acc: 0.9500 - val_loss: 3.2443 - val_acc: 0.4373
# Epoch 56/150
#  - 8s - loss: 0.2942 - acc: 0.9533 - val_loss: 3.2503 - val_acc: 0.4345
# Epoch 57/150
#  - 8s - loss: 0.2828 - acc: 0.9533 - val_loss: 3.2400 - val_acc: 0.4373
# Epoch 58/150
#  - 8s - loss: 0.2792 - acc: 0.9533 - val_loss: 3.2368 - val_acc: 0.4318
# Epoch 59/150
#  - 8s - loss: 0.2685 - acc: 0.9567 - val_loss: 3.2353 - val_acc: 0.4373
# Epoch 60/150
#  - 8s - loss: 0.2604 - acc: 0.9600 - val_loss: 3.2370 - val_acc: 0.4401
# Epoch 61/150
#  - 8s - loss: 0.2547 - acc: 0.9633 - val_loss: 3.2411 - val_acc: 0.4373
# Epoch 62/150
#  - 8s - loss: 0.2482 - acc: 0.9633 - val_loss: 3.2352 - val_acc: 0.4345
# Epoch 63/150
#  - 8s - loss: 0.2433 - acc: 0.9633 - val_loss: 3.2322 - val_acc: 0.4345
# Epoch 64/150
#  - 8s - loss: 0.2367 - acc: 0.9633 - val_loss: 3.2278 - val_acc: 0.4373
# Epoch 65/150
#  - 8s - loss: 0.2319 - acc: 0.9633 - val_loss: 3.2277 - val_acc: 0.4401
# Epoch 66/150
#  - 8s - loss: 0.2258 - acc: 0.9633 - val_loss: 3.2239 - val_acc: 0.4401
# Epoch 67/150
#  - 8s - loss: 0.2215 - acc: 0.9700 - val_loss: 3.2241 - val_acc: 0.4401
# Epoch 68/150
#  - 8s - loss: 0.2161 - acc: 0.9700 - val_loss: 3.2206 - val_acc: 0.4401
# Epoch 69/150
#  - 8s - loss: 0.2110 - acc: 0.9700 - val_loss: 3.2147 - val_acc: 0.4401
# Epoch 70/150
#  - 8s - loss: 0.2075 - acc: 0.9700 - val_loss: 3.2192 - val_acc: 0.4373
# Epoch 71/150
#  - 8s - loss: 0.2035 - acc: 0.9733 - val_loss: 3.2178 - val_acc: 0.4373
# Epoch 72/150
#  - 8s - loss: 0.2002 - acc: 0.9733 - val_loss: 3.2139 - val_acc: 0.4373
# Epoch 73/150
#  - 8s - loss: 0.1944 - acc: 0.9733 - val_loss: 3.2149 - val_acc: 0.4373
# Epoch 74/150
#  - 8s - loss: 0.1906 - acc: 0.9767 - val_loss: 3.2167 - val_acc: 0.4373
# Epoch 75/150
#  - 8s - loss: 0.1869 - acc: 0.9767 - val_loss: 3.2096 - val_acc: 0.4345
# Epoch 76/150
#  - 8s - loss: 0.1840 - acc: 0.9800 - val_loss: 3.2108 - val_acc: 0.4345
# Epoch 77/150
#  - 8s - loss: 0.1806 - acc: 0.9800 - val_loss: 3.2118 - val_acc: 0.4345
# Epoch 78/150
#  - 8s - loss: 0.1776 - acc: 0.9800 - val_loss: 3.2149 - val_acc: 0.4290
# Epoch 79/150
#  - 8s - loss: 0.1750 - acc: 0.9800 - val_loss: 3.2082 - val_acc: 0.4318
# Epoch 80/150
#  - 8s - loss: 0.1719 - acc: 0.9800 - val_loss: 3.2141 - val_acc: 0.4290
# Epoch 81/150
#  - 8s - loss: 0.1685 - acc: 0.9833 - val_loss: 3.2039 - val_acc: 0.4373
# Epoch 82/150
#  - 8s - loss: 0.1659 - acc: 0.9833 - val_loss: 3.2071 - val_acc: 0.4318
# Epoch 83/150
#  - 8s - loss: 0.1633 - acc: 0.9800 - val_loss: 3.2156 - val_acc: 0.4318
# Epoch 84/150
#  - 8s - loss: 0.1605 - acc: 0.9833 - val_loss: 3.2075 - val_acc: 0.4318
# Epoch 85/150
#  - 8s - loss: 0.1573 - acc: 0.9833 - val_loss: 3.2079 - val_acc: 0.4318
# Epoch 86/150
#  - 8s - loss: 0.1551 - acc: 0.9833 - val_loss: 3.2097 - val_acc: 0.4318
# Epoch 87/150
#  - 8s - loss: 0.1531 - acc: 0.9833 - val_loss: 3.2031 - val_acc: 0.4318
# Epoch 88/150
#  - 8s - loss: 0.1506 - acc: 0.9833 - val_loss: 3.2059 - val_acc: 0.4318
# Epoch 89/150
#  - 8s - loss: 0.1486 - acc: 0.9833 - val_loss: 3.2065 - val_acc: 0.4318
# Epoch 90/150
#  - 8s - loss: 0.1468 - acc: 0.9833 - val_loss: 3.2054 - val_acc: 0.4318
# Epoch 91/150
#  - 8s - loss: 0.1454 - acc: 0.9867 - val_loss: 3.2051 - val_acc: 0.4290
# Epoch 92/150
#  - 8s - loss: 0.1425 - acc: 0.9900 - val_loss: 3.1980 - val_acc: 0.4290
# Epoch 93/150
#  - 8s - loss: 0.1412 - acc: 0.9900 - val_loss: 3.1990 - val_acc: 0.4345
# Epoch 94/150
#  - 8s - loss: 0.1393 - acc: 0.9900 - val_loss: 3.2029 - val_acc: 0.4290
# Epoch 95/150
#  - 8s - loss: 0.1380 - acc: 0.9900 - val_loss: 3.2045 - val_acc: 0.4345
# Epoch 96/150
#  - 8s - loss: 0.1361 - acc: 0.9900 - val_loss: 3.1963 - val_acc: 0.4345
# Epoch 97/150
#  - 8s - loss: 0.1344 - acc: 0.9900 - val_loss: 3.2014 - val_acc: 0.4290
# Epoch 98/150
#  - 8s - loss: 0.1330 - acc: 0.9900 - val_loss: 3.2014 - val_acc: 0.4262
# Epoch 99/150
#  - 8s - loss: 0.1320 - acc: 0.9900 - val_loss: 3.2011 - val_acc: 0.4290
# Epoch 100/150
#  - 8s - loss: 0.1301 - acc: 0.9900 - val_loss: 3.1980 - val_acc: 0.4262
# Epoch 101/150
#  - 8s - loss: 0.1288 - acc: 0.9900 - val_loss: 3.1957 - val_acc: 0.4290
# Epoch 102/150
#  - 8s - loss: 0.1273 - acc: 0.9900 - val_loss: 3.1960 - val_acc: 0.4262
# Epoch 103/150
#  - 8s - loss: 0.1261 - acc: 0.9900 - val_loss: 3.2000 - val_acc: 0.4262
# Epoch 104/150
#  - 8s - loss: 0.1249 - acc: 0.9900 - val_loss: 3.1964 - val_acc: 0.4290
# Epoch 105/150
#  - 8s - loss: 0.1236 - acc: 0.9933 - val_loss: 3.1964 - val_acc: 0.4290
# Epoch 106/150
#  - 8s - loss: 0.1225 - acc: 0.9933 - val_loss: 3.1981 - val_acc: 0.4318
# Epoch 107/150
#  - 8s - loss: 0.1215 - acc: 0.9933 - val_loss: 3.1992 - val_acc: 0.4318
# Epoch 108/150
#  - 8s - loss: 0.1201 - acc: 0.9933 - val_loss: 3.1998 - val_acc: 0.4262
# Epoch 109/150
#  - 8s - loss: 0.1195 - acc: 0.9933 - val_loss: 3.2002 - val_acc: 0.4262
# Epoch 110/150
#  - 8s - loss: 0.1183 - acc: 0.9933 - val_loss: 3.2022 - val_acc: 0.4262
# Epoch 111/150
#  - 8s - loss: 0.1173 - acc: 0.9933 - val_loss: 3.1964 - val_acc: 0.4290
# Epoch 112/150
#  - 8s - loss: 0.1166 - acc: 0.9933 - val_loss: 3.1948 - val_acc: 0.4318
# Epoch 113/150
#  - 8s - loss: 0.1152 - acc: 0.9933 - val_loss: 3.1987 - val_acc: 0.4290
# Epoch 114/150
#  - 8s - loss: 0.1146 - acc: 0.9933 - val_loss: 3.1986 - val_acc: 0.4290
# Epoch 115/150
#  - 8s - loss: 0.1132 - acc: 0.9933 - val_loss: 3.1941 - val_acc: 0.4318
# Epoch 116/150
#  - 8s - loss: 0.1129 - acc: 0.9933 - val_loss: 3.1971 - val_acc: 0.4290
# Epoch 117/150
#  - 8s - loss: 0.1118 - acc: 0.9967 - val_loss: 3.2027 - val_acc: 0.4290
# Epoch 118/150
#  - 8s - loss: 0.1110 - acc: 0.9967 - val_loss: 3.1980 - val_acc: 0.4262
# Epoch 119/150
#  - 8s - loss: 0.1101 - acc: 0.9967 - val_loss: 3.1976 - val_acc: 0.4290
# Epoch 120/150
#  - 8s - loss: 0.1093 - acc: 0.9967 - val_loss: 3.1955 - val_acc: 0.4318
# Epoch 121/150
#  - 8s - loss: 0.1087 - acc: 0.9967 - val_loss: 3.1964 - val_acc: 0.4290
# Epoch 122/150
#  - 8s - loss: 0.1079 - acc: 0.9967 - val_loss: 3.1962 - val_acc: 0.4290
# Epoch 123/150
#  - 8s - loss: 0.1073 - acc: 0.9967 - val_loss: 3.1972 - val_acc: 0.4290
# Epoch 124/150
#  - 8s - loss: 0.1065 - acc: 0.9967 - val_loss: 3.1973 - val_acc: 0.4290
# Epoch 125/150
#  - 8s - loss: 0.1059 - acc: 0.9967 - val_loss: 3.1982 - val_acc: 0.4290
# Epoch 126/150
#  - 8s - loss: 0.1056 - acc: 0.9967 - val_loss: 3.1954 - val_acc: 0.4318
# Epoch 127/150
#  - 8s - loss: 0.1048 - acc: 0.9967 - val_loss: 3.1967 - val_acc: 0.4318
# Epoch 128/150
#  - 8s - loss: 0.1042 - acc: 0.9967 - val_loss: 3.1966 - val_acc: 0.4290
# Epoch 129/150
#  - 8s - loss: 0.1037 - acc: 0.9967 - val_loss: 3.1948 - val_acc: 0.4290
# Epoch 130/150
#  - 8s - loss: 0.1031 - acc: 0.9967 - val_loss: 3.1959 - val_acc: 0.4290
# Epoch 131/150
#  - 8s - loss: 0.1027 - acc: 0.9967 - val_loss: 3.1965 - val_acc: 0.4290
# Epoch 132/150
#  - 8s - loss: 0.1020 - acc: 0.9967 - val_loss: 3.1918 - val_acc: 0.4290
# Epoch 133/150
#  - 8s - loss: 0.1014 - acc: 0.9967 - val_loss: 3.1919 - val_acc: 0.4318
# Epoch 134/150
#  - 8s - loss: 0.1009 - acc: 0.9967 - val_loss: 3.1937 - val_acc: 0.4290
# Epoch 135/150
#  - 8s - loss: 0.1004 - acc: 0.9967 - val_loss: 3.1927 - val_acc: 0.4345
# Epoch 136/150
#  - 8s - loss: 0.1001 - acc: 0.9967 - val_loss: 3.1939 - val_acc: 0.4345
# Epoch 137/150
#  - 8s - loss: 0.0995 - acc: 0.9967 - val_loss: 3.1941 - val_acc: 0.4290
# Epoch 138/150
#  - 8s - loss: 0.0990 - acc: 0.9967 - val_loss: 3.1934 - val_acc: 0.4290
# Epoch 139/150
#  - 8s - loss: 0.0986 - acc: 0.9967 - val_loss: 3.1930 - val_acc: 0.4290
# Epoch 140/150
#  - 8s - loss: 0.0981 - acc: 0.9967 - val_loss: 3.1954 - val_acc: 0.4345
# Epoch 141/150
#  - 8s - loss: 0.0977 - acc: 0.9967 - val_loss: 3.1930 - val_acc: 0.4373
# Epoch 142/150
#  - 8s - loss: 0.0973 - acc: 0.9967 - val_loss: 3.1919 - val_acc: 0.4318
# Epoch 143/150
#  - 8s - loss: 0.0970 - acc: 0.9967 - val_loss: 3.1946 - val_acc: 0.4345
# Epoch 144/150
#  - 8s - loss: 0.0965 - acc: 0.9967 - val_loss: 3.1911 - val_acc: 0.4290
# Epoch 145/150
#  - 8s - loss: 0.0960 - acc: 0.9967 - val_loss: 3.1911 - val_acc: 0.4290
# Epoch 146/150
#  - 8s - loss: 0.0956 - acc: 0.9967 - val_loss: 3.1919 - val_acc: 0.4345
# Epoch 147/150
#  - 8s - loss: 0.0951 - acc: 0.9967 - val_loss: 3.1919 - val_acc: 0.4373
# Epoch 148/150
#  - 8s - loss: 0.0951 - acc: 0.9967 - val_loss: 3.1912 - val_acc: 0.4373
# Epoch 149/150
#  - 8s - loss: 0.0945 - acc: 0.9967 - val_loss: 3.1956 - val_acc: 0.4345
# Epoch 150/150
#  - 8s - loss: 0.0941 - acc: 0.9967 - val_loss: 3.1957 - val_acc: 0.4318
# Timing:  1198.4489703178406
# model_info_3 history Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/hist_my_VGG16_03_256filt_gu0_50nod_2.pkl
# add line
# df_res_filters_gu0_50nod Saved here:
# /content/drive/My Drive/OpenClassRooms/IML_Projet_6/data/df_res_filters_gu0_50nod.pkl
# nb_filters:  320
# nb_try:  0
# Model: "my_VGG16_03_320filt_gu0_50nod_0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 224, 224, 320)     8960
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 112, 112, 320)     0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 112, 112, 320)     921920
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 56, 56, 320)       0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 1003520)           0
# _________________________________________________________________
# dense_29 (Dense)             (None, 50)                50176050
# _________________________________________________________________
# dense_30 (Dense)             (None, 3)                 153
# =================================================================
# Total params: 51,107,083
# Trainable params: 51,107,083
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Train on 300 samples, validate on 359 samples
# Epoch 1/150
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-31-cdc0e73cf240> in <module>()
#      75                                 batch_size=batch_size, verbose=2,
#      76                                 validation_data=(X_test, Y_test),
# ---> 77                                 callbacks=[es])
#      78     t_fit_1 = time.time()
#      79     print("Timing: ", t_fit_1 - t_fit_0)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[32,320,224,224] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node training_14/SGD/gradients/max_pooling2d_29/MaxPool_grad/MaxPoolGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %% [markdown]
# #### Compare

# %%
df_res_filters_gu0_50nod
# Out:
#                                  acc_test  acc_train  nb_filters  nb_try  \
# my_VGG16_03_64filt_gu0_50nod_0   0.387187   0.906667        64.0     0.0
# my_VGG16_03_64filt_gu0_50nod_1   0.389972   0.903333        64.0     1.0
# my_VGG16_03_64filt_gu0_50nod_2   0.376045   0.913333        64.0     2.0
# my_VGG16_03_128filt_gu0_50nod_0  0.428969   0.976667       128.0     0.0
# my_VGG16_03_128filt_gu0_50nod_1  0.420613   0.973333       128.0     1.0
# my_VGG16_03_128filt_gu0_50nod_2  0.423398   0.960000       128.0     2.0
# my_VGG16_03_256filt_gu0_50nod_0  0.440111   0.996667       256.0     0.0
# my_VGG16_03_256filt_gu0_50nod_1  0.434540   0.996667       256.0     1.0
# my_VGG16_03_256filt_gu0_50nod_2  0.431755   0.996667       256.0     2.0
#
#                                        t_fit    t_pred
# my_VGG16_03_64filt_gu0_50nod_0    278.967669  1.143587
# my_VGG16_03_64filt_gu0_50nod_1    278.466687  1.169961
# my_VGG16_03_64filt_gu0_50nod_2    278.685001  1.186586
# my_VGG16_03_128filt_gu0_50nod_0   569.346708  2.179522
# my_VGG16_03_128filt_gu0_50nod_1   506.795024  2.194590
# my_VGG16_03_128filt_gu0_50nod_2   488.134610  2.228237
# my_VGG16_03_256filt_gu0_50nod_0  1207.053412  4.388344
# my_VGG16_03_256filt_gu0_50nod_1  1206.822917  4.349530
# my_VGG16_03_256filt_gu0_50nod_2  1198.448970  4.437499

# %%
print("Loading from disk df_results...")
df_results = joblib.load(path_df_results)
print("Loading from disk df_res_filters...")
df_res_filters = joblib.load(path_data + 'df_res_filters.pkl')
print("Loading from disk df_res_nodes...")
df_res_nodes = joblib.load(path_data + 'df_res_nodes.pkl')
print("Loading from disk df_res_filters_max...")
df_res_filters_max = joblib.load(path_data + 'df_res_filters_max.pkl')
print("Loading from disk df_res_filters_he_50nod.pkl...")
df_res_filters_he_50nod = joblib.load(path_data + 'df_res_filters_he_50nod.pkl')
print("Loading from disk df_res_filters_gu0_50nod.pkl...")
df_res_filters_gu0_50nod = joblib.load(path_data + 'df_res_filters_gu0_50nod.pkl')
# Out:
# Loading from disk df_results...
# Loading from disk df_res_filters...
# Loading from disk df_res_nodes...
# Loading from disk df_res_filters_max...
# Loading from disk df_res_filters_he_50nod.pkl...
# Loading from disk df_res_filters_gu0_50nod.pkl...

# %%
sns.catplot(x="nb_filters", y="acc_test", kind="box", 
            data=df_res_filters_gu0_50nod);

# %%
ax = sns.regplot(x="nb_filters", y="acc_test", data=df_res_filters_gu0_50nod);
ax.set_title("Improve accuracy with nb conv. filters");

# %%
ax = sns.regplot(x="nb_filters", y="t_fit", data=df_res_filters_gu0_50nod);
ax.set_title("Increase of time with number of conv. filters")
# Out:
# Text(0.5, 1.0, 'Increase of time with number of conv. filters')

# %%
nb_splits = df_res_filters_gu0_50nod["nb_try"].nunique()
def confid_interv(value):
  return 1.96*np.std(value)/np.sqrt(nb_splits)
df_filters = df_res_filters_gu0_50nod.pivot_table(values=["acc_test",	
                                                         "acc_train", 
                                                "t_fit",	"t_pred"],
                           index="nb_filters", aggfunc={np.mean, confid_interv})
df_filters
# Out:
#                 acc_test               acc_train                   t_fit  \
#            confid_interv      mean confid_interv      mean confid_interv
# nb_filters
# 64.0            0.006809  0.384401      0.004705  0.907778      0.232078
# 128.0           0.003931  0.424327      0.008148  0.970000     39.302094
# 256.0           0.003931  0.435469      0.000000  0.996667      4.529765
#
#                                t_pred
#                    mean confid_interv      mean
# nb_filters
# 64.0         278.706452      0.020034  1.166711
# 128.0        521.425447      0.023044  2.200783
# 256.0       1204.108433      0.040733  4.391791

# %%
df_filters["nb_filters"] = df_filters.index
ax = sns.regplot(x=df_filters["nb_filters"] , y=df_filters[("acc_test","mean")]);
ax.set_title("Improve mean test accuracy with nb conv. filters");
ax.set_ylim([0.3,0.5])
plt.errorbar(df_filters["nb_filters"], df_filters[("acc_test","mean")], 
             yerr=df_filters[("acc_test","confid_interv")], uplims=True, 
             lolims=True);

# %% [markdown]
# #### Loop overs runs / 256 filters / 50 nodes FC / initialization HE normal random  (10 runs)
#
# Random again to look for better results

# %%
name_df_res = 'df_res_256filt_50nod_he'
